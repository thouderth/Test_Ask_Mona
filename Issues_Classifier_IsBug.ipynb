# %% [markdown]
# ### Extraire les names des labels

# %%
import pandas as pd
def labelsToName(df2):
    df2["label_names"]=df2["labels"].apply(\
        lambda ligne: #fct anonyme \
                    "no_labels" if len(ligne) == 0 # le if \
                     else ",".join(map( #on parcourt la list de dico \
                              lambda dico: dico["name"] #on prend le name dans le dico \
                             ,ligne))\
                  )

# %% [markdown]
# ### Importer les données de plusieurs pages

# %%
 def importerEtTraiterLesIssusLabels(maxi=10,page=30):
        a_concat=[]
        giveMePage = lambda i: pd.read_json("https://api.github.com/repos/Microsoft/vscode/issues?per_page=%d&page=%d" % (page,i))
        dfA = giveMePage(1)
        i=0
        while  dfA.size > 0 and i<maxi:
            labelsToName(dfA)
            a_concat.append(dfA)
            dfA = giveMePage(1)
            i+=1
    #print(len(a_concat))
        pdd=pd.concat(a_concat,ignore_index=True)
        pdd["isBug"]=d["label_names"].str.contains("bug",regex=True)
        pdd["isFR"]=d["label_names"].str.contains("feature\-request",regex=True)
        pdd["isOther"] = ~d["label_names"].str.contains("bug|feature\-request")
        return pdd

# %%
d=importerEtTraiterLesIssusLabels(maxi=10,page=30)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-10-4686199a40be> in <module>()
# ----> 1 d=importerEtTraiterLesIssusLabels(maxi=10,page=30)
#
# <ipython-input-9-bf3d6b8ad5ac> in importerEtTraiterLesIssusLabels(maxi, page)
#       2        a_concat=[]
#       3        giveMePage = lambda i: pd.read_json("https://api.github.com/repos/Microsoft/vscode/issues?per_page=%d&page=%d" % (page,i))
# ----> 4        dfA = giveMePage(1)
#       5        i=0
#       6        while  dfA.size > 0 and i<maxi:
#
# <ipython-input-9-bf3d6b8ad5ac> in <lambda>(i)
#       1 def importerEtTraiterLesIssusLabels(maxi=10,page=30):
#       2        a_concat=[]
# ----> 3        giveMePage = lambda i: pd.read_json("https://api.github.com/repos/Microsoft/vscode/issues?per_page=%d&page=%d" % (page,i))
#       4        dfA = giveMePage(1)
#       5        i=0
#
# c:\users\thouderth\appdata\local\programs\python\python36\lib\site-packages\pandas\io\json\json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     350     compression = _infer_compression(path_or_buf, compression)
#     351     filepath_or_buffer, _, compression = get_filepath_or_buffer(
# --> 352         path_or_buf, encoding=encoding, compression=compression,
#     353     )
#     354
#
# c:\users\thouderth\appdata\local\programs\python\python36\lib\site-packages\pandas\io\common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression)
#     188
#     189     if _is_url(filepath_or_buffer):
# --> 190         req = _urlopen(filepath_or_buffer)
#     191         content_encoding = req.headers.get('Content-Encoding', None)
#     192         if content_encoding == 'gzip':
#
# c:\users\thouderth\appdata\local\programs\python\python36\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# c:\users\thouderth\appdata\local\programs\python\python36\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# c:\users\thouderth\appdata\local\programs\python\python36\lib\urllib\request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# c:\users\thouderth\appdata\local\programs\python\python36\lib\urllib\request.py in error(self, proto, *args)
#     568         if http_err:
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#     572 # XXX probably also want an abstract factory that knows when it makes
#
# c:\users\thouderth\appdata\local\programs\python\python36\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# c:\users\thouderth\appdata\local\programs\python\python36\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648 class HTTPDefaultErrorHandler(BaseHandler):
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#     652 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden

# %%
d
# Out:
#                                               assignee  \
# 0                                                 None
# 1    {'login': 'isidorn', 'id': 1926584, 'node_id':...
# 2                                                 None
# 3                                                 None
# 4                                                 None
# 5    {'login': 'Tyriar', 'id': 2193314, 'node_id': ...
# 6    {'login': 'sbatten', 'id': 6561887, 'node_id':...
# 7                                                 None
# 8    {'login': 'ramya-rao-a', 'id': 16890566, 'node...
# 9                                                 None
# 10   {'login': 'jrieken', 'id': 1794099, 'node_id':...
# 11   {'login': 'jrieken', 'id': 1794099, 'node_id':...
# 12                                                None
# 13   {'login': 'mjbvz', 'id': 12821956, 'node_id': ...
# 14   {'login': 'joaomoreno', 'id': 22350, 'node_id'...
# 15                                                None
# 16                                                None
# 17                                                None
# 18                                                None
# 19                                                None
# 20                                                None
# 21                                                None
# 22                                                None
# 23                                                None
# 24   {'login': 'sbatten', 'id': 6561887, 'node_id':...
# 25   {'login': 'weinand', 'id': 1898161, 'node_id':...
# 26   {'login': 'bpasero', 'id': 900690, 'node_id': ...
# 27                                                None
# 28   {'login': 'weinand', 'id': 1898161, 'node_id':...
# 29                                                None
# ..                                                 ...
# 270                                               None
# 271  {'login': 'isidorn', 'id': 1926584, 'node_id':...
# 272                                               None
# 273                                               None
# 274                                               None
# 275  {'login': 'Tyriar', 'id': 2193314, 'node_id': ...
# 276  {'login': 'sbatten', 'id': 6561887, 'node_id':...
# 277                                               None
# 278  {'login': 'ramya-rao-a', 'id': 16890566, 'node...
# 279                                               None
# 280  {'login': 'jrieken', 'id': 1794099, 'node_id':...
# 281  {'login': 'jrieken', 'id': 1794099, 'node_id':...
# 282                                               None
# 283  {'login': 'mjbvz', 'id': 12821956, 'node_id': ...
# 284  {'login': 'joaomoreno', 'id': 22350, 'node_id'...
# 285                                               None
# 286                                               None
# 287                                               None
# 288                                               None
# 289                                               None
# 290                                               None
# 291                                               None
# 292                                               None
# 293                                               None
# 294  {'login': 'sbatten', 'id': 6561887, 'node_id':...
# 295  {'login': 'weinand', 'id': 1898161, 'node_id':...
# 296  {'login': 'bpasero', 'id': 900690, 'node_id': ...
# 297                                               None
# 298  {'login': 'weinand', 'id': 1898161, 'node_id':...
# 299                                               None
#
#                                              assignees author_association  \
# 0                                                   []               NONE
# 1    [{'login': 'isidorn', 'id': 1926584, 'node_id'...               NONE
# 2                                                   []               NONE
# 3                                                   []               NONE
# 4                                                   []               NONE
# 5    [{'login': 'Tyriar', 'id': 2193314, 'node_id':...               NONE
# 6    [{'login': 'sbatten', 'id': 6561887, 'node_id'...             MEMBER
# 7                                                   []               NONE
# 8    [{'login': 'ramya-rao-a', 'id': 16890566, 'nod...               NONE
# 9                                                   []               NONE
# 10   [{'login': 'jrieken', 'id': 1794099, 'node_id'...               NONE
# 11   [{'login': 'jrieken', 'id': 1794099, 'node_id'...        CONTRIBUTOR
# 12                                                  []               NONE
# 13   [{'login': 'mjbvz', 'id': 12821956, 'node_id':...               NONE
# 14   [{'login': 'joaomoreno', 'id': 22350, 'node_id...             MEMBER
# 15                                                  []               NONE
# 16                                                  []             MEMBER
# 17                                                  []             MEMBER
# 18                                                  []               NONE
# 19                                                  []               NONE
# 20                                                  []               NONE
# 21                                                  []               NONE
# 22                                                  []               NONE
# 23                                                  []               NONE
# 24   [{'login': 'sbatten', 'id': 6561887, 'node_id'...             MEMBER
# 25   [{'login': 'weinand', 'id': 1898161, 'node_id'...               NONE
# 26   [{'login': 'bpasero', 'id': 900690, 'node_id':...        CONTRIBUTOR
# 27                                                  []               NONE
# 28   [{'login': 'weinand', 'id': 1898161, 'node_id'...               NONE
# 29                                                  []               NONE
# ..                                                 ...                ...
# 270                                                 []               NONE
# 271  [{'login': 'isidorn', 'id': 1926584, 'node_id'...               NONE
# 272                                                 []               NONE
# 273                                                 []               NONE
# 274                                                 []               NONE
# 275  [{'login': 'Tyriar', 'id': 2193314, 'node_id':...               NONE
# 276  [{'login': 'sbatten', 'id': 6561887, 'node_id'...             MEMBER
# 277                                                 []               NONE
# 278  [{'login': 'ramya-rao-a', 'id': 16890566, 'nod...               NONE
# 279                                                 []               NONE
# 280  [{'login': 'jrieken', 'id': 1794099, 'node_id'...               NONE
# 281  [{'login': 'jrieken', 'id': 1794099, 'node_id'...        CONTRIBUTOR
# 282                                                 []               NONE
# 283  [{'login': 'mjbvz', 'id': 12821956, 'node_id':...               NONE
# 284  [{'login': 'joaomoreno', 'id': 22350, 'node_id...             MEMBER
# 285                                                 []               NONE
# 286                                                 []             MEMBER
# 287                                                 []             MEMBER
# 288                                                 []               NONE
# 289                                                 []               NONE
# 290                                                 []               NONE
# 291                                                 []               NONE
# 292                                                 []               NONE
# 293                                                 []               NONE
# 294  [{'login': 'sbatten', 'id': 6561887, 'node_id'...             MEMBER
# 295  [{'login': 'weinand', 'id': 1898161, 'node_id'...               NONE
# 296  [{'login': 'bpasero', 'id': 900690, 'node_id':...        CONTRIBUTOR
# 297                                                 []               NONE
# 298  [{'login': 'weinand', 'id': 1898161, 'node_id'...               NONE
# 299                                                 []               NONE
#
#                                                   body closed_at  comments  \
# 0    This option will allow opt-out of restoring sc...       NaT         1
# 1    I have a very large web application with 21 mu...       NaT         0
# 2    Currently you can use compound launch configur...       NaT         0
# 3    Seria bueno de irme abrir el vinculo delas cap...       NaT         0
# 4    Issue Type: <b>Bug</b>\r\n\r\nInstall VSCode I...       NaT         0
# 5    hi again :wave:\r\n\r\ni'm trying to customize...       NaT         0
# 6    ![image](https://user-images.githubusercontent...       NaT         0
# 7    Issue Type: <b>Bug</b>\r\n\r\nlooking another ...       NaT         0
# 8    Issue Type: <b>Bug</b>\r\n\r\nSteps to reprodu...       NaT         1
# 9    I recreate this formerly closed feature reques...       NaT         0
# 10   <!-- Please search existing issues to avoid cr...       NaT         0
# 11   > __NOTE__\r\n> There is a duplicate and simil...       NaT         0
# 12   <!-- Please search existing issues to avoid cr...       NaT         0
# 13   \r\nIssue Type: <b>Bug</b>\r\n\r\nI expected t...       NaT         0
# 14                                                           NaT         0
# 15                     所需的数据太大，无法直接发送。我们已经将其写入剪贴板，请粘贴。       NaT         2
# 16   CC: @joaomoreno @chrisrpatterson\r\nThis PR ad...       NaT         0
# 17   The VSTS YAML should be updated for the latest...       NaT         0
# 18   Dear,\r\n\r\nWould be great if, using simple f...       NaT         0
# 19   Like in VisualStudio 201x, will be great to be...       NaT         0
# 20   Sublime has a feature where I can perform a fi...       NaT         0
# 21   When I click on "Help - Relesae notes", an emp...       NaT         1
# 22   Its as simple as providing and address bar for...       NaT         0
# 23   Can we scroll horizontally using our mouse scr...       NaT         1
# 24   - OS Version: Windows 10\r\n\r\nSteps to Repro...       NaT         0
# 25   When debugging & stopping at a breakpoint, I o...       NaT         1
# 26   This closes #57536 \r\n\r\n@bpasero I've made ...       NaT         0
# 27   Issue Type: <b>Bug</b>\r\n\r\nwhenever i try t...       NaT         1
# 28   Issue Type: <b>Bug</b>\r\n\r\nCreate a simple ...       NaT         1
# 29   Using the px2rem plugin, some units have to be...       NaT         1
# ..                                                 ...       ...       ...
# 270  This option will allow opt-out of restoring sc...       NaT         1
# 271  I have a very large web application with 21 mu...       NaT         0
# 272  Currently you can use compound launch configur...       NaT         0
# 273  Seria bueno de irme abrir el vinculo delas cap...       NaT         0
# 274  Issue Type: <b>Bug</b>\r\n\r\nInstall VSCode I...       NaT         0
# 275  hi again :wave:\r\n\r\ni'm trying to customize...       NaT         0
# 276  ![image](https://user-images.githubusercontent...       NaT         0
# 277  Issue Type: <b>Bug</b>\r\n\r\nlooking another ...       NaT         0
# 278  Issue Type: <b>Bug</b>\r\n\r\nSteps to reprodu...       NaT         1
# 279  I recreate this formerly closed feature reques...       NaT         0
# 280  <!-- Please search existing issues to avoid cr...       NaT         0
# 281  > __NOTE__\r\n> There is a duplicate and simil...       NaT         0
# 282  <!-- Please search existing issues to avoid cr...       NaT         0
# 283  \r\nIssue Type: <b>Bug</b>\r\n\r\nI expected t...       NaT         0
# 284                                                          NaT         0
# 285                    所需的数据太大，无法直接发送。我们已经将其写入剪贴板，请粘贴。       NaT         2
# 286  CC: @joaomoreno @chrisrpatterson\r\nThis PR ad...       NaT         0
# 287  The VSTS YAML should be updated for the latest...       NaT         0
# 288  Dear,\r\n\r\nWould be great if, using simple f...       NaT         0
# 289  Like in VisualStudio 201x, will be great to be...       NaT         0
# 290  Sublime has a feature where I can perform a fi...       NaT         0
# 291  When I click on "Help - Relesae notes", an emp...       NaT         1
# 292  Its as simple as providing and address bar for...       NaT         0
# 293  Can we scroll horizontally using our mouse scr...       NaT         1
# 294  - OS Version: Windows 10\r\n\r\nSteps to Repro...       NaT         0
# 295  When debugging & stopping at a breakpoint, I o...       NaT         1
# 296  This closes #57536 \r\n\r\n@bpasero I've made ...       NaT         0
# 297  Issue Type: <b>Bug</b>\r\n\r\nwhenever i try t...       NaT         1
# 298  Issue Type: <b>Bug</b>\r\n\r\nCreate a simple ...       NaT         1
# 299  Using the px2rem plugin, some units have to be...       NaT         1
#
#                                           comments_url          created_at  \
# 0    https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 22:13:54
# 1    https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 22:09:38
# 2    https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 21:31:04
# 3    https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 21:30:53
# 4    https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 20:58:29
# 5    https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 20:28:59
# 6    https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 20:11:24
# 7    https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 19:17:56
# 8    https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 18:50:36
# 9    https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 18:25:54
# 10   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 18:03:47
# 11   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 17:13:15
# 12   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 15:29:57
# 13   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 15:22:40
# 14   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 14:32:59
# 15   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 13:57:17
# 16   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 13:24:03
# 17   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 13:18:39
# 18   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 13:12:16
# 19   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 13:08:23
# 20   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 12:57:14
# 21   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 12:25:42
# 22   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 09:22:16
# 23   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 07:35:13
# 24   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 07:02:45
# 25   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 06:29:44
# 26   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 05:50:19
# 27   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 05:39:08
# 28   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 05:27:50
# 29   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 02:51:18
# ..                                                 ...                 ...
# 270  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 22:13:54
# 271  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 22:09:38
# 272  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 21:31:04
# 273  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 21:30:53
# 274  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 20:58:29
# 275  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 20:28:59
# 276  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 20:11:24
# 277  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 19:17:56
# 278  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 18:50:36
# 279  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 18:25:54
# 280  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 18:03:47
# 281  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 17:13:15
# 282  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 15:29:57
# 283  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 15:22:40
# 284  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 14:32:59
# 285  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 13:57:17
# 286  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 13:24:03
# 287  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 13:18:39
# 288  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 13:12:16
# 289  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 13:08:23
# 290  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 12:57:14
# 291  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 12:25:42
# 292  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 09:22:16
# 293  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 07:35:13
# 294  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 07:02:45
# 295  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 06:29:44
# 296  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 05:50:19
# 297  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 05:39:08
# 298  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 05:27:50
# 299  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 02:51:18
#
#                                             events_url  \
# 0    https://api.github.com/repos/Microsoft/vscode/...
# 1    https://api.github.com/repos/Microsoft/vscode/...
# 2    https://api.github.com/repos/Microsoft/vscode/...
# 3    https://api.github.com/repos/Microsoft/vscode/...
# 4    https://api.github.com/repos/Microsoft/vscode/...
# 5    https://api.github.com/repos/Microsoft/vscode/...
# 6    https://api.github.com/repos/Microsoft/vscode/...
# 7    https://api.github.com/repos/Microsoft/vscode/...
# 8    https://api.github.com/repos/Microsoft/vscode/...
# 9    https://api.github.com/repos/Microsoft/vscode/...
# 10   https://api.github.com/repos/Microsoft/vscode/...
# 11   https://api.github.com/repos/Microsoft/vscode/...
# 12   https://api.github.com/repos/Microsoft/vscode/...
# 13   https://api.github.com/repos/Microsoft/vscode/...
# 14   https://api.github.com/repos/Microsoft/vscode/...
# 15   https://api.github.com/repos/Microsoft/vscode/...
# 16   https://api.github.com/repos/Microsoft/vscode/...
# 17   https://api.github.com/repos/Microsoft/vscode/...
# 18   https://api.github.com/repos/Microsoft/vscode/...
# 19   https://api.github.com/repos/Microsoft/vscode/...
# 20   https://api.github.com/repos/Microsoft/vscode/...
# 21   https://api.github.com/repos/Microsoft/vscode/...
# 22   https://api.github.com/repos/Microsoft/vscode/...
# 23   https://api.github.com/repos/Microsoft/vscode/...
# 24   https://api.github.com/repos/Microsoft/vscode/...
# 25   https://api.github.com/repos/Microsoft/vscode/...
# 26   https://api.github.com/repos/Microsoft/vscode/...
# 27   https://api.github.com/repos/Microsoft/vscode/...
# 28   https://api.github.com/repos/Microsoft/vscode/...
# 29   https://api.github.com/repos/Microsoft/vscode/...
# ..                                                 ...
# 270  https://api.github.com/repos/Microsoft/vscode/...
# 271  https://api.github.com/repos/Microsoft/vscode/...
# 272  https://api.github.com/repos/Microsoft/vscode/...
# 273  https://api.github.com/repos/Microsoft/vscode/...
# 274  https://api.github.com/repos/Microsoft/vscode/...
# 275  https://api.github.com/repos/Microsoft/vscode/...
# 276  https://api.github.com/repos/Microsoft/vscode/...
# 277  https://api.github.com/repos/Microsoft/vscode/...
# 278  https://api.github.com/repos/Microsoft/vscode/...
# 279  https://api.github.com/repos/Microsoft/vscode/...
# 280  https://api.github.com/repos/Microsoft/vscode/...
# 281  https://api.github.com/repos/Microsoft/vscode/...
# 282  https://api.github.com/repos/Microsoft/vscode/...
# 283  https://api.github.com/repos/Microsoft/vscode/...
# 284  https://api.github.com/repos/Microsoft/vscode/...
# 285  https://api.github.com/repos/Microsoft/vscode/...
# 286  https://api.github.com/repos/Microsoft/vscode/...
# 287  https://api.github.com/repos/Microsoft/vscode/...
# 288  https://api.github.com/repos/Microsoft/vscode/...
# 289  https://api.github.com/repos/Microsoft/vscode/...
# 290  https://api.github.com/repos/Microsoft/vscode/...
# 291  https://api.github.com/repos/Microsoft/vscode/...
# 292  https://api.github.com/repos/Microsoft/vscode/...
# 293  https://api.github.com/repos/Microsoft/vscode/...
# 294  https://api.github.com/repos/Microsoft/vscode/...
# 295  https://api.github.com/repos/Microsoft/vscode/...
# 296  https://api.github.com/repos/Microsoft/vscode/...
# 297  https://api.github.com/repos/Microsoft/vscode/...
# 298  https://api.github.com/repos/Microsoft/vscode/...
# 299  https://api.github.com/repos/Microsoft/vscode/...
#
#                                              html_url   ...    \
# 0      https://github.com/Microsoft/vscode/pull/57762   ...
# 1    https://github.com/Microsoft/vscode/issues/57761   ...
# 2    https://github.com/Microsoft/vscode/issues/57760   ...
# 3    https://github.com/Microsoft/vscode/issues/57759   ...
# 4    https://github.com/Microsoft/vscode/issues/57758   ...
# 5    https://github.com/Microsoft/vscode/issues/57757   ...
# 6    https://github.com/Microsoft/vscode/issues/57756   ...
# 7    https://github.com/Microsoft/vscode/issues/57755   ...
# 8    https://github.com/Microsoft/vscode/issues/57754   ...
# 9    https://github.com/Microsoft/vscode/issues/57753   ...
# 10   https://github.com/Microsoft/vscode/issues/57751   ...
# 11   https://github.com/Microsoft/vscode/issues/57750   ...
# 12   https://github.com/Microsoft/vscode/issues/57749   ...
# 13   https://github.com/Microsoft/vscode/issues/57748   ...
# 14     https://github.com/Microsoft/vscode/pull/57747   ...
# 15   https://github.com/Microsoft/vscode/issues/57746   ...
# 16     https://github.com/Microsoft/vscode/pull/57745   ...
# 17   https://github.com/Microsoft/vscode/issues/57744   ...
# 18   https://github.com/Microsoft/vscode/issues/57743   ...
# 19   https://github.com/Microsoft/vscode/issues/57742   ...
# 20   https://github.com/Microsoft/vscode/issues/57741   ...
# 21   https://github.com/Microsoft/vscode/issues/57740   ...
# 22   https://github.com/Microsoft/vscode/issues/57738   ...
# 23   https://github.com/Microsoft/vscode/issues/57737   ...
# 24   https://github.com/Microsoft/vscode/issues/57736   ...
# 25   https://github.com/Microsoft/vscode/issues/57735   ...
# 26     https://github.com/Microsoft/vscode/pull/57734   ...
# 27   https://github.com/Microsoft/vscode/issues/57733   ...
# 28   https://github.com/Microsoft/vscode/issues/57732   ...
# 29   https://github.com/Microsoft/vscode/issues/57731   ...
# ..                                                ...   ...
# 270    https://github.com/Microsoft/vscode/pull/57762   ...
# 271  https://github.com/Microsoft/vscode/issues/57761   ...
# 272  https://github.com/Microsoft/vscode/issues/57760   ...
# 273  https://github.com/Microsoft/vscode/issues/57759   ...
# 274  https://github.com/Microsoft/vscode/issues/57758   ...
# 275  https://github.com/Microsoft/vscode/issues/57757   ...
# 276  https://github.com/Microsoft/vscode/issues/57756   ...
# 277  https://github.com/Microsoft/vscode/issues/57755   ...
# 278  https://github.com/Microsoft/vscode/issues/57754   ...
# 279  https://github.com/Microsoft/vscode/issues/57753   ...
# 280  https://github.com/Microsoft/vscode/issues/57751   ...
# 281  https://github.com/Microsoft/vscode/issues/57750   ...
# 282  https://github.com/Microsoft/vscode/issues/57749   ...
# 283  https://github.com/Microsoft/vscode/issues/57748   ...
# 284    https://github.com/Microsoft/vscode/pull/57747   ...
# 285  https://github.com/Microsoft/vscode/issues/57746   ...
# 286    https://github.com/Microsoft/vscode/pull/57745   ...
# 287  https://github.com/Microsoft/vscode/issues/57744   ...
# 288  https://github.com/Microsoft/vscode/issues/57743   ...
# 289  https://github.com/Microsoft/vscode/issues/57742   ...
# 290  https://github.com/Microsoft/vscode/issues/57741   ...
# 291  https://github.com/Microsoft/vscode/issues/57740   ...
# 292  https://github.com/Microsoft/vscode/issues/57738   ...
# 293  https://github.com/Microsoft/vscode/issues/57737   ...
# 294  https://github.com/Microsoft/vscode/issues/57736   ...
# 295  https://github.com/Microsoft/vscode/issues/57735   ...
# 296    https://github.com/Microsoft/vscode/pull/57734   ...
# 297  https://github.com/Microsoft/vscode/issues/57733   ...
# 298  https://github.com/Microsoft/vscode/issues/57732   ...
# 299  https://github.com/Microsoft/vscode/issues/57731   ...
#
#                                     repository_url state  \
# 0    https://api.github.com/repos/Microsoft/vscode  open
# 1    https://api.github.com/repos/Microsoft/vscode  open
# 2    https://api.github.com/repos/Microsoft/vscode  open
# 3    https://api.github.com/repos/Microsoft/vscode  open
# 4    https://api.github.com/repos/Microsoft/vscode  open
# 5    https://api.github.com/repos/Microsoft/vscode  open
# 6    https://api.github.com/repos/Microsoft/vscode  open
# 7    https://api.github.com/repos/Microsoft/vscode  open
# 8    https://api.github.com/repos/Microsoft/vscode  open
# 9    https://api.github.com/repos/Microsoft/vscode  open
# 10   https://api.github.com/repos/Microsoft/vscode  open
# 11   https://api.github.com/repos/Microsoft/vscode  open
# 12   https://api.github.com/repos/Microsoft/vscode  open
# 13   https://api.github.com/repos/Microsoft/vscode  open
# 14   https://api.github.com/repos/Microsoft/vscode  open
# 15   https://api.github.com/repos/Microsoft/vscode  open
# 16   https://api.github.com/repos/Microsoft/vscode  open
# 17   https://api.github.com/repos/Microsoft/vscode  open
# 18   https://api.github.com/repos/Microsoft/vscode  open
# 19   https://api.github.com/repos/Microsoft/vscode  open
# 20   https://api.github.com/repos/Microsoft/vscode  open
# 21   https://api.github.com/repos/Microsoft/vscode  open
# 22   https://api.github.com/repos/Microsoft/vscode  open
# 23   https://api.github.com/repos/Microsoft/vscode  open
# 24   https://api.github.com/repos/Microsoft/vscode  open
# 25   https://api.github.com/repos/Microsoft/vscode  open
# 26   https://api.github.com/repos/Microsoft/vscode  open
# 27   https://api.github.com/repos/Microsoft/vscode  open
# 28   https://api.github.com/repos/Microsoft/vscode  open
# 29   https://api.github.com/repos/Microsoft/vscode  open
# ..                                             ...   ...
# 270  https://api.github.com/repos/Microsoft/vscode  open
# 271  https://api.github.com/repos/Microsoft/vscode  open
# 272  https://api.github.com/repos/Microsoft/vscode  open
# 273  https://api.github.com/repos/Microsoft/vscode  open
# 274  https://api.github.com/repos/Microsoft/vscode  open
# 275  https://api.github.com/repos/Microsoft/vscode  open
# 276  https://api.github.com/repos/Microsoft/vscode  open
# 277  https://api.github.com/repos/Microsoft/vscode  open
# 278  https://api.github.com/repos/Microsoft/vscode  open
# 279  https://api.github.com/repos/Microsoft/vscode  open
# 280  https://api.github.com/repos/Microsoft/vscode  open
# 281  https://api.github.com/repos/Microsoft/vscode  open
# 282  https://api.github.com/repos/Microsoft/vscode  open
# 283  https://api.github.com/repos/Microsoft/vscode  open
# 284  https://api.github.com/repos/Microsoft/vscode  open
# 285  https://api.github.com/repos/Microsoft/vscode  open
# 286  https://api.github.com/repos/Microsoft/vscode  open
# 287  https://api.github.com/repos/Microsoft/vscode  open
# 288  https://api.github.com/repos/Microsoft/vscode  open
# 289  https://api.github.com/repos/Microsoft/vscode  open
# 290  https://api.github.com/repos/Microsoft/vscode  open
# 291  https://api.github.com/repos/Microsoft/vscode  open
# 292  https://api.github.com/repos/Microsoft/vscode  open
# 293  https://api.github.com/repos/Microsoft/vscode  open
# 294  https://api.github.com/repos/Microsoft/vscode  open
# 295  https://api.github.com/repos/Microsoft/vscode  open
# 296  https://api.github.com/repos/Microsoft/vscode  open
# 297  https://api.github.com/repos/Microsoft/vscode  open
# 298  https://api.github.com/repos/Microsoft/vscode  open
# 299  https://api.github.com/repos/Microsoft/vscode  open
#
#                                                  title          updated_at  \
# 0                   Add editor.restoreViewState option 2018-09-01 22:21:27
# 1           Active workspace detection for launch.json 2018-09-01 22:26:19
# 2    Ability to run multiple launch events sequenti... 2018-09-01 22:24:54
# 3                     Se necesita agregar mas opciones 2018-09-01 21:33:55
# 4                Output window is showing incorrect UI 2018-09-01 20:58:33
# 5    Setting default `executable` in ShellExecution... 2018-09-01 20:29:20
# 6    No menu overflow causes problems with narrow w... 2018-09-01 20:11:24
# 7                                  Try after installed 2018-09-01 19:17:56
# 8    Emmet 'Wrap with Abbreviation' doesn't work in... 2018-09-01 18:50:57
# 9    Option to insert comment // characters at colu... 2018-09-01 18:26:16
# 10     Nested tabstops in snippets behaves incorrectly 2018-09-01 18:04:06
# 11   Request for Access to Ambient Light Sensor in ... 2018-09-01 17:13:34
# 12   TextDocumentContentProvider renders gibberish ... 2018-09-01 15:30:44
# 13              I do not see the Markdown Preview icon 2018-09-01 17:20:28
# 14                              Automate macOS signing 2018-09-01 14:35:53
# 15                                   重新打开后不直接显示之前打开的项目 2018-09-01 15:04:13
# 16                        Use the new VSTS YAML syntax 2018-09-01 14:18:50
# 17                 Use new VSTS YAML syntax for builds 2018-09-01 13:19:00
# 18                 Find "all" references in a document 2018-09-01 13:12:37
# 19                Notice ends of document when finding 2018-09-01 13:08:44
# 20                                  Find -> Select All 2018-09-01 12:57:35
# 21                            Don't show release notes 2018-09-01 12:25:47
# 22   Tree View Controls, Address bar, with focus, e... 2018-09-01 09:23:42
# 23                                Horizontal scrollbar 2018-09-01 07:35:33
# 24   Windows: custom context menu does not close wh... 2018-09-01 07:02:45
# 25   Add "execute next line", not just "step over n... 2018-09-01 08:54:51
# 26    add option for input validation foreground color 2018-09-01 06:00:22
# 27             Extension failed to download everytime. 2018-09-01 05:39:28
# 28                    Nodejs debugger infinite restart 2018-09-01 08:50:36
# 29   How to shield CSS units from being automatical... 2018-09-01 05:49:33
# ..                                                 ...                 ...
# 270                 Add editor.restoreViewState option 2018-09-01 22:21:27
# 271         Active workspace detection for launch.json 2018-09-01 22:26:19
# 272  Ability to run multiple launch events sequenti... 2018-09-01 22:24:54
# 273                   Se necesita agregar mas opciones 2018-09-01 21:33:55
# 274              Output window is showing incorrect UI 2018-09-01 20:58:33
# 275  Setting default `executable` in ShellExecution... 2018-09-01 20:29:20
# 276  No menu overflow causes problems with narrow w... 2018-09-01 20:11:24
# 277                                Try after installed 2018-09-01 19:17:56
# 278  Emmet 'Wrap with Abbreviation' doesn't work in... 2018-09-01 18:50:57
# 279  Option to insert comment // characters at colu... 2018-09-01 18:26:16
# 280    Nested tabstops in snippets behaves incorrectly 2018-09-01 18:04:06
# 281  Request for Access to Ambient Light Sensor in ... 2018-09-01 17:13:34
# 282  TextDocumentContentProvider renders gibberish ... 2018-09-01 15:30:44
# 283             I do not see the Markdown Preview icon 2018-09-01 17:20:28
# 284                             Automate macOS signing 2018-09-01 14:35:53
# 285                                  重新打开后不直接显示之前打开的项目 2018-09-01 15:04:13
# 286                       Use the new VSTS YAML syntax 2018-09-01 14:18:50
# 287                Use new VSTS YAML syntax for builds 2018-09-01 13:19:00
# 288                Find "all" references in a document 2018-09-01 13:12:37
# 289               Notice ends of document when finding 2018-09-01 13:08:44
# 290                                 Find -> Select All 2018-09-01 12:57:35
# 291                           Don't show release notes 2018-09-01 12:25:47
# 292  Tree View Controls, Address bar, with focus, e... 2018-09-01 09:23:42
# 293                               Horizontal scrollbar 2018-09-01 07:35:33
# 294  Windows: custom context menu does not close wh... 2018-09-01 07:02:45
# 295  Add "execute next line", not just "step over n... 2018-09-01 08:54:51
# 296   add option for input validation foreground color 2018-09-01 06:00:22
# 297            Extension failed to download everytime. 2018-09-01 05:39:28
# 298                   Nodejs debugger infinite restart 2018-09-01 08:50:36
# 299  How to shield CSS units from being automatical... 2018-09-01 05:49:33
#
#                                                    url  \
# 0    https://api.github.com/repos/Microsoft/vscode/...
# 1    https://api.github.com/repos/Microsoft/vscode/...
# 2    https://api.github.com/repos/Microsoft/vscode/...
# 3    https://api.github.com/repos/Microsoft/vscode/...
# 4    https://api.github.com/repos/Microsoft/vscode/...
# 5    https://api.github.com/repos/Microsoft/vscode/...
# 6    https://api.github.com/repos/Microsoft/vscode/...
# 7    https://api.github.com/repos/Microsoft/vscode/...
# 8    https://api.github.com/repos/Microsoft/vscode/...
# 9    https://api.github.com/repos/Microsoft/vscode/...
# 10   https://api.github.com/repos/Microsoft/vscode/...
# 11   https://api.github.com/repos/Microsoft/vscode/...
# 12   https://api.github.com/repos/Microsoft/vscode/...
# 13   https://api.github.com/repos/Microsoft/vscode/...
# 14   https://api.github.com/repos/Microsoft/vscode/...
# 15   https://api.github.com/repos/Microsoft/vscode/...
# 16   https://api.github.com/repos/Microsoft/vscode/...
# 17   https://api.github.com/repos/Microsoft/vscode/...
# 18   https://api.github.com/repos/Microsoft/vscode/...
# 19   https://api.github.com/repos/Microsoft/vscode/...
# 20   https://api.github.com/repos/Microsoft/vscode/...
# 21   https://api.github.com/repos/Microsoft/vscode/...
# 22   https://api.github.com/repos/Microsoft/vscode/...
# 23   https://api.github.com/repos/Microsoft/vscode/...
# 24   https://api.github.com/repos/Microsoft/vscode/...
# 25   https://api.github.com/repos/Microsoft/vscode/...
# 26   https://api.github.com/repos/Microsoft/vscode/...
# 27   https://api.github.com/repos/Microsoft/vscode/...
# 28   https://api.github.com/repos/Microsoft/vscode/...
# 29   https://api.github.com/repos/Microsoft/vscode/...
# ..                                                 ...
# 270  https://api.github.com/repos/Microsoft/vscode/...
# 271  https://api.github.com/repos/Microsoft/vscode/...
# 272  https://api.github.com/repos/Microsoft/vscode/...
# 273  https://api.github.com/repos/Microsoft/vscode/...
# 274  https://api.github.com/repos/Microsoft/vscode/...
# 275  https://api.github.com/repos/Microsoft/vscode/...
# 276  https://api.github.com/repos/Microsoft/vscode/...
# 277  https://api.github.com/repos/Microsoft/vscode/...
# 278  https://api.github.com/repos/Microsoft/vscode/...
# 279  https://api.github.com/repos/Microsoft/vscode/...
# 280  https://api.github.com/repos/Microsoft/vscode/...
# 281  https://api.github.com/repos/Microsoft/vscode/...
# 282  https://api.github.com/repos/Microsoft/vscode/...
# 283  https://api.github.com/repos/Microsoft/vscode/...
# 284  https://api.github.com/repos/Microsoft/vscode/...
# 285  https://api.github.com/repos/Microsoft/vscode/...
# 286  https://api.github.com/repos/Microsoft/vscode/...
# 287  https://api.github.com/repos/Microsoft/vscode/...
# 288  https://api.github.com/repos/Microsoft/vscode/...
# 289  https://api.github.com/repos/Microsoft/vscode/...
# 290  https://api.github.com/repos/Microsoft/vscode/...
# 291  https://api.github.com/repos/Microsoft/vscode/...
# 292  https://api.github.com/repos/Microsoft/vscode/...
# 293  https://api.github.com/repos/Microsoft/vscode/...
# 294  https://api.github.com/repos/Microsoft/vscode/...
# 295  https://api.github.com/repos/Microsoft/vscode/...
# 296  https://api.github.com/repos/Microsoft/vscode/...
# 297  https://api.github.com/repos/Microsoft/vscode/...
# 298  https://api.github.com/repos/Microsoft/vscode/...
# 299  https://api.github.com/repos/Microsoft/vscode/...
#
#                                                   user  \
# 0    {'login': 'aviddiviner', 'id': 835967, 'node_i...
# 1    {'login': 'richbully', 'id': 11023398, 'node_i...
# 2    {'login': 'ChaosCA', 'id': 5280764, 'node_id':...
# 3    {'login': 'WilsonGrave', 'id': 42899255, 'node...
# 4    {'login': 'wizchick7', 'id': 1242893, 'node_id...
# 5    {'login': 'busticated', 'id': 367674, 'node_id...
# 6    {'login': 'Tyriar', 'id': 2193314, 'node_id': ...
# 7    {'login': 'transdigiware', 'id': 34800339, 'no...
# 8    {'login': 'bencun', 'id': 15714548, 'node_id':...
# 9    {'login': 's-kocher', 'id': 27820864, 'node_id...
# 10   {'login': 'yangshuairocks', 'id': 39968, 'node...
# 11   {'login': 'pmkary', 'id': 2157285, 'node_id': ...
# 12   {'login': 'Almenon', 'id': 13080965, 'node_id'...
# 13   {'login': 'pelos6', 'id': 3807895, 'node_id': ...
# 14   {'login': 'joaomoreno', 'id': 22350, 'node_id'...
# 15   {'login': 'wyxnl', 'id': 42760723, 'node_id': ...
# 16   {'login': 'DavidStaheli', 'id': 1767415, 'node...
# 17   {'login': 'DavidStaheli', 'id': 1767415, 'node...
# 18   {'login': 'michaelsogos', 'id': 971120, 'node_...
# 19   {'login': 'michaelsogos', 'id': 971120, 'node_...
# 20   {'login': 'cjbarth', 'id': 3049726, 'node_id':...
# 21   {'login': 'IDIDIR', 'id': 21132031, 'node_id':...
# 22   {'login': 'wesleyolis', 'id': 2478837, 'node_i...
# 23   {'login': 'alifrontend499', 'id': 34374927, 'n...
# 24   {'login': 'bpasero', 'id': 900690, 'node_id': ...
# 25   {'login': 'steinhh', 'id': 12274643, 'node_id'...
# 26   {'login': 'ParkourKarthik', 'id': 9585305, 'no...
# 27   {'login': 'iamRavikantSingh', 'id': 40258150, ...
# 28   {'login': 'Lev09', 'id': 4953382, 'node_id': '...
# 29   {'login': 'youshao', 'id': 11664572, 'node_id'...
# ..                                                 ...
# 270  {'login': 'aviddiviner', 'id': 835967, 'node_i...
# 271  {'login': 'richbully', 'id': 11023398, 'node_i...
# 272  {'login': 'ChaosCA', 'id': 5280764, 'node_id':...
# 273  {'login': 'WilsonGrave', 'id': 42899255, 'node...
# 274  {'login': 'wizchick7', 'id': 1242893, 'node_id...
# 275  {'login': 'busticated', 'id': 367674, 'node_id...
# 276  {'login': 'Tyriar', 'id': 2193314, 'node_id': ...
# 277  {'login': 'transdigiware', 'id': 34800339, 'no...
# 278  {'login': 'bencun', 'id': 15714548, 'node_id':...
# 279  {'login': 's-kocher', 'id': 27820864, 'node_id...
# 280  {'login': 'yangshuairocks', 'id': 39968, 'node...
# 281  {'login': 'pmkary', 'id': 2157285, 'node_id': ...
# 282  {'login': 'Almenon', 'id': 13080965, 'node_id'...
# 283  {'login': 'pelos6', 'id': 3807895, 'node_id': ...
# 284  {'login': 'joaomoreno', 'id': 22350, 'node_id'...
# 285  {'login': 'wyxnl', 'id': 42760723, 'node_id': ...
# 286  {'login': 'DavidStaheli', 'id': 1767415, 'node...
# 287  {'login': 'DavidStaheli', 'id': 1767415, 'node...
# 288  {'login': 'michaelsogos', 'id': 971120, 'node_...
# 289  {'login': 'michaelsogos', 'id': 971120, 'node_...
# 290  {'login': 'cjbarth', 'id': 3049726, 'node_id':...
# 291  {'login': 'IDIDIR', 'id': 21132031, 'node_id':...
# 292  {'login': 'wesleyolis', 'id': 2478837, 'node_i...
# 293  {'login': 'alifrontend499', 'id': 34374927, 'n...
# 294  {'login': 'bpasero', 'id': 900690, 'node_id': ...
# 295  {'login': 'steinhh', 'id': 12274643, 'node_id'...
# 296  {'login': 'ParkourKarthik', 'id': 9585305, 'no...
# 297  {'login': 'iamRavikantSingh', 'id': 40258150, ...
# 298  {'login': 'Lev09', 'id': 4953382, 'node_id': '...
# 299  {'login': 'youshao', 'id': 11664572, 'node_id'...
#
#                   label_names  isBug   isFR isOther
# 0                   no_labels  False  False    True
# 1    debug,feature-request,ux   True   True   False
# 2       debug,feature-request   True   True   False
# 3                   no_labels  False  False    True
# 4                    insiders  False  False    True
# 5         integrated-terminal  False  False    True
# 6          bug,workbench-menu   True  False   False
# 7                   no_labels  False  False    True
# 8                       emmet  False  False    True
# 9       editor,editor-contrib  False  False    True
# 10                  no_labels  False  False    True
# 11                  no_labels  False  False    True
# 12                  no_labels  False  False    True
# 13                   markdown  False  False    True
# 14   engineering,vscode-build  False  False    True
# 15                  no_labels  False  False    True
# 16                  no_labels  False  False    True
# 17            languages basic  False  False    True
# 18                  no_labels  False  False    True
# 19         editor,editor-find  False  False    True
# 20         editor,editor-find  False  False    True
# 21                  no_labels  False  False    True
# 22                  no_labels  False  False    True
# 23                     editor  False  False    True
# 24         bug,workbench-menu   True  False   False
# 25      debug,needs more info   True  False   False
# 26                  no_labels  False  False    True
# 27                 extensions  False  False    True
# 28      debug,needs more info   True  False   False
# 29                  no_labels  False  False    True
# ..                        ...    ...    ...     ...
# 270                 no_labels  False  False    True
# 271  debug,feature-request,ux   True   True   False
# 272     debug,feature-request   True   True   False
# 273                 no_labels  False  False    True
# 274                  insiders  False  False    True
# 275       integrated-terminal  False  False    True
# 276        bug,workbench-menu   True  False   False
# 277                 no_labels  False  False    True
# 278                     emmet  False  False    True
# 279     editor,editor-contrib  False  False    True
# 280                 no_labels  False  False    True
# 281                 no_labels  False  False    True
# 282                 no_labels  False  False    True
# 283                  markdown  False  False    True
# 284  engineering,vscode-build  False  False    True
# 285                 no_labels  False  False    True
# 286                 no_labels  False  False    True
# 287           languages basic  False  False    True
# 288                 no_labels  False  False    True
# 289        editor,editor-find  False  False    True
# 290        editor,editor-find  False  False    True
# 291                 no_labels  False  False    True
# 292                 no_labels  False  False    True
# 293                    editor  False  False    True
# 294        bug,workbench-menu   True  False   False
# 295     debug,needs more info   True  False   False
# 296                 no_labels  False  False    True
# 297                extensions  False  False    True
# 298     debug,needs more info   True  False   False
# 299                 no_labels  False  False    True
#
# [300 rows x 28 columns]

# %% [markdown]
# ### Extraire les variables qui m'interesse

# %%
col = ['label_names','body','isBug']
dcol = d[col]
dcol
# Out:
#                   label_names  \
# 0                   no_labels
# 1    debug,feature-request,ux
# 2       debug,feature-request
# 3                   no_labels
# 4                    insiders
# 5         integrated-terminal
# 6          bug,workbench-menu
# 7                   no_labels
# 8                       emmet
# 9       editor,editor-contrib
# 10                  no_labels
# 11                  no_labels
# 12                  no_labels
# 13                   markdown
# 14   engineering,vscode-build
# 15                  no_labels
# 16                  no_labels
# 17            languages basic
# 18                  no_labels
# 19         editor,editor-find
# 20         editor,editor-find
# 21                  no_labels
# 22                  no_labels
# 23                     editor
# 24         bug,workbench-menu
# 25      debug,needs more info
# 26                  no_labels
# 27                 extensions
# 28      debug,needs more info
# 29                  no_labels
# ..                        ...
# 270                 no_labels
# 271  debug,feature-request,ux
# 272     debug,feature-request
# 273                 no_labels
# 274                  insiders
# 275       integrated-terminal
# 276        bug,workbench-menu
# 277                 no_labels
# 278                     emmet
# 279     editor,editor-contrib
# 280                 no_labels
# 281                 no_labels
# 282                 no_labels
# 283                  markdown
# 284  engineering,vscode-build
# 285                 no_labels
# 286                 no_labels
# 287           languages basic
# 288                 no_labels
# 289        editor,editor-find
# 290        editor,editor-find
# 291                 no_labels
# 292                 no_labels
# 293                    editor
# 294        bug,workbench-menu
# 295     debug,needs more info
# 296                 no_labels
# 297                extensions
# 298     debug,needs more info
# 299                 no_labels
#
#                                                   body  isBug
# 0    This option will allow opt-out of restoring sc...  False
# 1    I have a very large web application with 21 mu...   True
# 2    Currently you can use compound launch configur...   True
# 3    Seria bueno de irme abrir el vinculo delas cap...  False
# 4    Issue Type: <b>Bug</b>\r\n\r\nInstall VSCode I...  False
# 5    hi again :wave:\r\n\r\ni'm trying to customize...  False
# 6    ![image](https://user-images.githubusercontent...   True
# 7    Issue Type: <b>Bug</b>\r\n\r\nlooking another ...  False
# 8    Issue Type: <b>Bug</b>\r\n\r\nSteps to reprodu...  False
# 9    I recreate this formerly closed feature reques...  False
# 10   <!-- Please search existing issues to avoid cr...  False
# 11   > __NOTE__\r\n> There is a duplicate and simil...  False
# 12   <!-- Please search existing issues to avoid cr...  False
# 13   \r\nIssue Type: <b>Bug</b>\r\n\r\nI expected t...  False
# 14                                                      False
# 15                     所需的数据太大，无法直接发送。我们已经将其写入剪贴板，请粘贴。  False
# 16   CC: @joaomoreno @chrisrpatterson\r\nThis PR ad...  False
# 17   The VSTS YAML should be updated for the latest...  False
# 18   Dear,\r\n\r\nWould be great if, using simple f...  False
# 19   Like in VisualStudio 201x, will be great to be...  False
# 20   Sublime has a feature where I can perform a fi...  False
# 21   When I click on "Help - Relesae notes", an emp...  False
# 22   Its as simple as providing and address bar for...  False
# 23   Can we scroll horizontally using our mouse scr...  False
# 24   - OS Version: Windows 10\r\n\r\nSteps to Repro...   True
# 25   When debugging & stopping at a breakpoint, I o...   True
# 26   This closes #57536 \r\n\r\n@bpasero I've made ...  False
# 27   Issue Type: <b>Bug</b>\r\n\r\nwhenever i try t...  False
# 28   Issue Type: <b>Bug</b>\r\n\r\nCreate a simple ...   True
# 29   Using the px2rem plugin, some units have to be...  False
# ..                                                 ...    ...
# 270  This option will allow opt-out of restoring sc...  False
# 271  I have a very large web application with 21 mu...   True
# 272  Currently you can use compound launch configur...   True
# 273  Seria bueno de irme abrir el vinculo delas cap...  False
# 274  Issue Type: <b>Bug</b>\r\n\r\nInstall VSCode I...  False
# 275  hi again :wave:\r\n\r\ni'm trying to customize...  False
# 276  ![image](https://user-images.githubusercontent...   True
# 277  Issue Type: <b>Bug</b>\r\n\r\nlooking another ...  False
# 278  Issue Type: <b>Bug</b>\r\n\r\nSteps to reprodu...  False
# 279  I recreate this formerly closed feature reques...  False
# 280  <!-- Please search existing issues to avoid cr...  False
# 281  > __NOTE__\r\n> There is a duplicate and simil...  False
# 282  <!-- Please search existing issues to avoid cr...  False
# 283  \r\nIssue Type: <b>Bug</b>\r\n\r\nI expected t...  False
# 284                                                     False
# 285                    所需的数据太大，无法直接发送。我们已经将其写入剪贴板，请粘贴。  False
# 286  CC: @joaomoreno @chrisrpatterson\r\nThis PR ad...  False
# 287  The VSTS YAML should be updated for the latest...  False
# 288  Dear,\r\n\r\nWould be great if, using simple f...  False
# 289  Like in VisualStudio 201x, will be great to be...  False
# 290  Sublime has a feature where I can perform a fi...  False
# 291  When I click on "Help - Relesae notes", an emp...  False
# 292  Its as simple as providing and address bar for...  False
# 293  Can we scroll horizontally using our mouse scr...  False
# 294  - OS Version: Windows 10\r\n\r\nSteps to Repro...   True
# 295  When debugging & stopping at a breakpoint, I o...   True
# 296  This closes #57536 \r\n\r\n@bpasero I've made ...  False
# 297  Issue Type: <b>Bug</b>\r\n\r\nwhenever i try t...  False
# 298  Issue Type: <b>Bug</b>\r\n\r\nCreate a simple ...   True
# 299  Using the px2rem plugin, some units have to be...  False
#
# [300 rows x 3 columns]

# %%
from io import StringIO
col = ['label_names', 'body','isBug']
d = d[col]
d.columns = ['label_names', 'body','isBug']
d['category_id'] = d['isBug'].factorize()[0]
category_id_d = d[['isBug', 'category_id']].drop_duplicates().sort_values('category_id')
category_to_id = dict(category_id_d.values)
id_to_category = dict(category_id_d[['category_id', 'isBug']].values)
d.head()
# Out:
# c:\users\thouderth\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                 label_names  \
# 0                 no_labels
# 1  debug,feature-request,ux
# 2     debug,feature-request
# 3                 no_labels
# 4                  insiders
#
#                                                 body  isBug  category_id
# 0  This option will allow opt-out of restoring sc...  False            0
# 1  I have a very large web application with 21 mu...   True            1
# 2  Currently you can use compound launch configur...   True            1
# 3  Seria bueno de irme abrir el vinculo delas cap...  False            0
# 4  Issue Type: <b>Bug</b>\r\n\r\nInstall VSCode I...  False            0

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')

features = tfidf.fit_transform(d.body).toarray()
labels = d.category_id
features.shape
# Out:
# (300, 2698)

# %%
from sklearn.feature_selection import chi2
import numpy as np
N = 2
for label_names, category_id in sorted(category_to_id.items()):
  features_chi2 = chi2(features, labels == category_id)
  indices = np.argsort(features_chi2[0])
  feature_names = np.array(tfidf.get_feature_names())[indices]
  unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
  bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
  print("# '{}':".format(label_names))
  print("  . Most correlated unigrams:\n. {}".format('\n. '.join(unigrams[-N:])))
  print("  . Most correlated bigrams:\n. {}".format('\n. '.join(bigrams[-N:])))
# Out:
# # 'False':
#   . Most correlated unigrams:
# . right
# . menu
#   . Most correlated bigrams:
# . right click
# . context menu
# # 'True':
#   . Most correlated unigrams:
# . right
# . menu
#   . Most correlated bigrams:
# . right click
# . context menu

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
X_train, X_test, y_train, y_test = train_test_split(d['body'], d['isBug'], random_state = 0)
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
clf
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
d['body'][276]
# Out:
# '![image](https://user-images.githubusercontent.com/2193314/44949529-6eef6200-ade8-11e8-89f0-ddde02a4191f.png)\r\n\r\nIt can also look like this after alt+f, right to terminal menu\r\n\r\n![image](https://user-images.githubusercontent.com/2193314/44949535-81699b80-ade8-11e8-9fa6-34359dd8643b.png)\r\n'

# %%
print(clf.predict(count_vect.transform(["![image](https://user-images.githubusercontent.com/2193314/44949529-6eef6200-ade8-11e8-89f0-ddde02a4191f.png)\r\n\r\nIt can also look like this after alt+f, right to terminal menu\r\n\r\n![image](https://user-images.githubusercontent.com/2193314/44949535-81699b80-ade8-11e8-9fa6-34359dd8643b.png)\r\n"])))
# Out:
# [ True]

# %%
d[d['body'] == "![image](https://user-images.githubusercontent.com/2193314/44949529-6eef6200-ade8-11e8-89f0-ddde02a4191f.png)\r\n\r\nIt can also look like this after alt+f, right to terminal menu\r\n\r\n![image](https://user-images.githubusercontent.com/2193314/44949535-81699b80-ade8-11e8-9fa6-34359dd8643b.png)\r\n"]
# Out:
#             label_names                                               body  \
# 6    bug,workbench-menu  ![image](https://user-images.githubusercontent...
# 36   bug,workbench-menu  ![image](https://user-images.githubusercontent...
# 66   bug,workbench-menu  ![image](https://user-images.githubusercontent...
# 96   bug,workbench-menu  ![image](https://user-images.githubusercontent...
# 126  bug,workbench-menu  ![image](https://user-images.githubusercontent...
# 156  bug,workbench-menu  ![image](https://user-images.githubusercontent...
# 186  bug,workbench-menu  ![image](https://user-images.githubusercontent...
# 216  bug,workbench-menu  ![image](https://user-images.githubusercontent...
# 246  bug,workbench-menu  ![image](https://user-images.githubusercontent...
# 276  bug,workbench-menu  ![image](https://user-images.githubusercontent...
#
#      isBug  category_id
# 6     True            1
# 36    True            1
# 66    True            1
# 96    True            1
# 126   True            1
# 156   True            1
# 186   True            1
# 216   True            1
# 246   True            1
# 276   True            1

# %% [markdown]
# ### Tester d'autre modeles de machine learning

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
models = [
    RandomForestClassifier(n_estimators=200, max_depth=3, random_state=0),
    LinearSVC(),
    MultinomialNB(),
    LogisticRegression(random_state=0),
]

cv_d = pd.DataFrame(index=range(CV * len(models)))
entries = []
for model in models:
    model_name = model.__class__.__name__
    accuracies = cross_val_score(model, features, labels, scoring='accuracy', cv=5)
    for fold_idx, accuracy in enumerate(accuracies):
        entries.append((model_name, fold_idx, accuracy))
cv_d = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])
cv_d.groupby('model_name').accuracy.mean()
# Out:
# model_name
# LinearSVC                 1.000000
# LogisticRegression        1.000000
# MultinomialNB             1.000000
# RandomForestClassifier    0.933333
# Name: accuracy, dtype: float64
