# %% [markdown]
# ### Extraire les names des labels

# %%
import pandas as pd
def labelsToName(df2):
    df2["label_names"]=df2["labels"].apply(\
        lambda ligne: #fct anonyme \
                    "no_labels" if len(ligne) == 0 # le if \
                     else ",".join(map( #on parcourt la list de dico \
                              lambda dico: dico["name"] #on prend le name dans le dico \
                             ,ligne))\
                  )

# %% [markdown]
# ### Importer les données de plusieurs pages

# %%
 def importerEtTraiterLesIssusLabels(maxi=10,page=30):
        a_concat=[]
        giveMePage = lambda i: pd.read_json("https://api.github.com/repos/Microsoft/vscode/issues?per_page=%d&page=%d" % (page,i))
        dfA = giveMePage(1)
        i=0
        while  dfA.size > 0 and i<maxi:
            labelsToName(dfA)
            a_concat.append(dfA)
            dfA = giveMePage(1)
            i+=1
    #print(len(a_concat))
        pdd=pd.concat(a_concat,ignore_index=True)
        pdd["isBug"] = pdd["label_names"].str.contains("bug",regex=True)
        pdd["isFR"] = pdd["label_names"].str.contains("feature\-request",regex=True)
        pdd["isOther"] = ~pdd["label_names"].str.contains("bug|feature\-request")
        return pdd

# %%
d=importerEtTraiterLesIssusLabels(maxi=10,page=30)

# %%
d
# Out:
#                                               assignee  \
# 0                                                 None
# 1    {'login': 'Tyriar', 'id': 2193314, 'node_id': ...
# 2    {'login': 'bpasero', 'id': 900690, 'node_id': ...
# 3                                                 None
# 4                                                 None
# 5                                                 None
# 6                                                 None
# 7    {'login': 'mjbvz', 'id': 12821956, 'node_id': ...
# 8                                                 None
# 9    {'login': 'sandy081', 'id': 10746682, 'node_id...
# 10   {'login': 'mjbvz', 'id': 12821956, 'node_id': ...
# 11                                                None
# 12                                                None
# 13                                                None
# 14                                                None
# 15                                                None
# 16                                                None
# 17   {'login': 'isidorn', 'id': 1926584, 'node_id':...
# 18                                                None
# 19                                                None
# 20                                                None
# 21   {'login': 'Tyriar', 'id': 2193314, 'node_id': ...
# 22   {'login': 'sbatten', 'id': 6561887, 'node_id':...
# 23                                                None
# 24   {'login': 'ramya-rao-a', 'id': 16890566, 'node...
# 25                                                None
# 26   {'login': 'jrieken', 'id': 1794099, 'node_id':...
# 27   {'login': 'jrieken', 'id': 1794099, 'node_id':...
# 28                                                None
# 29   {'login': 'mjbvz', 'id': 12821956, 'node_id': ...
# ..                                                 ...
# 270                                               None
# 271  {'login': 'Tyriar', 'id': 2193314, 'node_id': ...
# 272  {'login': 'bpasero', 'id': 900690, 'node_id': ...
# 273                                               None
# 274                                               None
# 275                                               None
# 276                                               None
# 277  {'login': 'mjbvz', 'id': 12821956, 'node_id': ...
# 278                                               None
# 279  {'login': 'sandy081', 'id': 10746682, 'node_id...
# 280  {'login': 'mjbvz', 'id': 12821956, 'node_id': ...
# 281                                               None
# 282                                               None
# 283                                               None
# 284                                               None
# 285                                               None
# 286                                               None
# 287  {'login': 'isidorn', 'id': 1926584, 'node_id':...
# 288                                               None
# 289                                               None
# 290                                               None
# 291  {'login': 'Tyriar', 'id': 2193314, 'node_id': ...
# 292  {'login': 'sbatten', 'id': 6561887, 'node_id':...
# 293                                               None
# 294  {'login': 'ramya-rao-a', 'id': 16890566, 'node...
# 295                                               None
# 296  {'login': 'jrieken', 'id': 1794099, 'node_id':...
# 297  {'login': 'jrieken', 'id': 1794099, 'node_id':...
# 298                                               None
# 299  {'login': 'mjbvz', 'id': 12821956, 'node_id': ...
#
#                                              assignees author_association  \
# 0                                                   []               NONE
# 1    [{'login': 'Tyriar', 'id': 2193314, 'node_id':...               NONE
# 2    [{'login': 'bpasero', 'id': 900690, 'node_id':...               NONE
# 3                                                   []               NONE
# 4                                                   []               NONE
# 5                                                   []               NONE
# 6                                                   []               NONE
# 7    [{'login': 'mjbvz', 'id': 12821956, 'node_id':...               NONE
# 8                                                   []               NONE
# 9    [{'login': 'sandy081', 'id': 10746682, 'node_i...             MEMBER
# 10   [{'login': 'mjbvz', 'id': 12821956, 'node_id':...               NONE
# 11                                                  []               NONE
# 12                                                  []               NONE
# 13                                                  []               NONE
# 14                                                  []               NONE
# 15                                                  []               NONE
# 16                                                  []               NONE
# 17   [{'login': 'isidorn', 'id': 1926584, 'node_id'...               NONE
# 18                                                  []               NONE
# 19                                                  []               NONE
# 20                                                  []               NONE
# 21   [{'login': 'Tyriar', 'id': 2193314, 'node_id':...               NONE
# 22   [{'login': 'sbatten', 'id': 6561887, 'node_id'...             MEMBER
# 23                                                  []               NONE
# 24   [{'login': 'ramya-rao-a', 'id': 16890566, 'nod...               NONE
# 25                                                  []               NONE
# 26   [{'login': 'jrieken', 'id': 1794099, 'node_id'...               NONE
# 27   [{'login': 'jrieken', 'id': 1794099, 'node_id'...        CONTRIBUTOR
# 28                                                  []               NONE
# 29   [{'login': 'mjbvz', 'id': 12821956, 'node_id':...               NONE
# ..                                                 ...                ...
# 270                                                 []               NONE
# 271  [{'login': 'Tyriar', 'id': 2193314, 'node_id':...               NONE
# 272  [{'login': 'bpasero', 'id': 900690, 'node_id':...               NONE
# 273                                                 []               NONE
# 274                                                 []               NONE
# 275                                                 []               NONE
# 276                                                 []               NONE
# 277  [{'login': 'mjbvz', 'id': 12821956, 'node_id':...               NONE
# 278                                                 []               NONE
# 279  [{'login': 'sandy081', 'id': 10746682, 'node_i...             MEMBER
# 280  [{'login': 'mjbvz', 'id': 12821956, 'node_id':...               NONE
# 281                                                 []               NONE
# 282                                                 []               NONE
# 283                                                 []               NONE
# 284                                                 []               NONE
# 285                                                 []               NONE
# 286                                                 []               NONE
# 287  [{'login': 'isidorn', 'id': 1926584, 'node_id'...               NONE
# 288                                                 []               NONE
# 289                                                 []               NONE
# 290                                                 []               NONE
# 291  [{'login': 'Tyriar', 'id': 2193314, 'node_id':...               NONE
# 292  [{'login': 'sbatten', 'id': 6561887, 'node_id'...             MEMBER
# 293                                                 []               NONE
# 294  [{'login': 'ramya-rao-a', 'id': 16890566, 'nod...               NONE
# 295                                                 []               NONE
# 296  [{'login': 'jrieken', 'id': 1794099, 'node_id'...               NONE
# 297  [{'login': 'jrieken', 'id': 1794099, 'node_id'...        CONTRIBUTOR
# 298                                                 []               NONE
# 299  [{'login': 'mjbvz', 'id': 12821956, 'node_id':...               NONE
#
#                                                   body closed_at  comments  \
# 0    <!-- Please search existing issues to avoid cr...       NaT         0
# 1    Issue Type: <b>Bug</b>\r\n\r\nAfter updating f...       NaT         0
# 2    <!-- Please search existing issues to avoid cr...       NaT         2
# 3    <!-- Please search existing issues to avoid cr...       NaT         0
# 4    - VSCode Version: Version: 1.26.1 (Commit: 493...       NaT         1
# 5    Issue Type: <b>Suspected Bug</b>\r\n\r\nI had ...       NaT         0
# 6    Issue Type: <b>Bug</b>\r\n\r\nSome menu items ...       NaT         1
# 7    VSCode Version: 1.26.1\r\nOS Version: MacOS\r\...       NaT         2
# 8    <!-- Please search existing issues to avoid cr...       NaT         1
# 9    - OS Version: macOS\r\n\r\nSteps to Reproduce:...       NaT         0
# 10   Issue Type: <b>Bug</b>\r\n\r\nWhen you make a ...       NaT         1
# 11   Pylint does not work in vs code if one of the ...       NaT         0
# 12   - VSCode Version: 1.26.1, 493869ee8e8a846b0855...       NaT         0
# 13   Issue Type: <b>Bug</b>\r\n\r\nBy default, ther...       NaT         1
# 14   The debugger for Java suddenly can't run.\r\nB...       NaT         0
# 15   I can open a new window, but it isn't cooperat...       NaT         1
# 16   This option will allow opt-out of restoring sc...       NaT         1
# 17   I have a very large web application with 21 mu...       NaT         0
# 18   Currently you can use compound launch configur...       NaT         0
# 19   Seria bueno de irme abrir el vinculo delas cap...       NaT         0
# 20   Issue Type: <b>Bug</b>\r\n\r\nInstall VSCode I...       NaT         0
# 21   hi again :wave:\r\n\r\ni'm trying to customize...       NaT         0
# 22   ![image](https://user-images.githubusercontent...       NaT         0
# 23   Issue Type: <b>Bug</b>\r\n\r\nlooking another ...       NaT         0
# 24   Issue Type: <b>Bug</b>\r\n\r\nSteps to reprodu...       NaT         1
# 25   I recreate this formerly closed feature reques...       NaT         0
# 26   <!-- Please search existing issues to avoid cr...       NaT         0
# 27   > __NOTE__\r\n> There is a duplicate and simil...       NaT         0
# 28   <!-- Please search existing issues to avoid cr...       NaT         0
# 29   \r\nIssue Type: <b>Bug</b>\r\n\r\nI expected t...       NaT         0
# ..                                                 ...       ...       ...
# 270  <!-- Please search existing issues to avoid cr...       NaT         0
# 271  Issue Type: <b>Bug</b>\r\n\r\nAfter updating f...       NaT         0
# 272  <!-- Please search existing issues to avoid cr...       NaT         2
# 273  <!-- Please search existing issues to avoid cr...       NaT         0
# 274  - VSCode Version: Version: 1.26.1 (Commit: 493...       NaT         1
# 275  Issue Type: <b>Suspected Bug</b>\r\n\r\nI had ...       NaT         0
# 276  Issue Type: <b>Bug</b>\r\n\r\nSome menu items ...       NaT         1
# 277  VSCode Version: 1.26.1\r\nOS Version: MacOS\r\...       NaT         2
# 278  <!-- Please search existing issues to avoid cr...       NaT         1
# 279  - OS Version: macOS\r\n\r\nSteps to Reproduce:...       NaT         0
# 280  Issue Type: <b>Bug</b>\r\n\r\nWhen you make a ...       NaT         1
# 281  Pylint does not work in vs code if one of the ...       NaT         0
# 282  - VSCode Version: 1.26.1, 493869ee8e8a846b0855...       NaT         0
# 283  Issue Type: <b>Bug</b>\r\n\r\nBy default, ther...       NaT         1
# 284  The debugger for Java suddenly can't run.\r\nB...       NaT         0
# 285  I can open a new window, but it isn't cooperat...       NaT         1
# 286  This option will allow opt-out of restoring sc...       NaT         1
# 287  I have a very large web application with 21 mu...       NaT         0
# 288  Currently you can use compound launch configur...       NaT         0
# 289  Seria bueno de irme abrir el vinculo delas cap...       NaT         0
# 290  Issue Type: <b>Bug</b>\r\n\r\nInstall VSCode I...       NaT         0
# 291  hi again :wave:\r\n\r\ni'm trying to customize...       NaT         0
# 292  ![image](https://user-images.githubusercontent...       NaT         0
# 293  Issue Type: <b>Bug</b>\r\n\r\nlooking another ...       NaT         0
# 294  Issue Type: <b>Bug</b>\r\n\r\nSteps to reprodu...       NaT         1
# 295  I recreate this formerly closed feature reques...       NaT         0
# 296  <!-- Please search existing issues to avoid cr...       NaT         0
# 297  > __NOTE__\r\n> There is a duplicate and simil...       NaT         0
# 298  <!-- Please search existing issues to avoid cr...       NaT         0
# 299  \r\nIssue Type: <b>Bug</b>\r\n\r\nI expected t...       NaT         0
#
#                                           comments_url          created_at  \
# 0    https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 15:21:29
# 1    https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 15:19:27
# 2    https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 14:57:04
# 3    https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 14:41:31
# 4    https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 14:17:17
# 5    https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 14:03:28
# 6    https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 13:03:10
# 7    https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 11:56:57
# 8    https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 10:08:10
# 9    https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 08:56:16
# 10   https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 07:37:48
# 11   https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 06:49:58
# 12   https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 03:59:57
# 13   https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 03:18:17
# 14   https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 03:17:03
# 15   https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 01:25:26
# 16   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 22:13:54
# 17   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 22:09:38
# 18   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 21:31:04
# 19   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 21:30:53
# 20   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 20:58:29
# 21   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 20:28:59
# 22   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 20:11:24
# 23   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 19:17:56
# 24   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 18:50:36
# 25   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 18:25:54
# 26   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 18:03:47
# 27   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 17:13:15
# 28   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 15:29:57
# 29   https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 15:22:40
# ..                                                 ...                 ...
# 270  https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 15:21:29
# 271  https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 15:19:27
# 272  https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 14:57:04
# 273  https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 14:41:31
# 274  https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 14:17:17
# 275  https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 14:03:28
# 276  https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 13:03:10
# 277  https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 11:56:57
# 278  https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 10:08:10
# 279  https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 08:56:16
# 280  https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 07:37:48
# 281  https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 06:49:58
# 282  https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 03:59:57
# 283  https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 03:18:17
# 284  https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 03:17:03
# 285  https://api.github.com/repos/Microsoft/vscode/... 2018-09-02 01:25:26
# 286  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 22:13:54
# 287  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 22:09:38
# 288  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 21:31:04
# 289  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 21:30:53
# 290  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 20:58:29
# 291  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 20:28:59
# 292  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 20:11:24
# 293  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 19:17:56
# 294  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 18:50:36
# 295  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 18:25:54
# 296  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 18:03:47
# 297  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 17:13:15
# 298  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 15:29:57
# 299  https://api.github.com/repos/Microsoft/vscode/... 2018-09-01 15:22:40
#
#                                             events_url  \
# 0    https://api.github.com/repos/Microsoft/vscode/...
# 1    https://api.github.com/repos/Microsoft/vscode/...
# 2    https://api.github.com/repos/Microsoft/vscode/...
# 3    https://api.github.com/repos/Microsoft/vscode/...
# 4    https://api.github.com/repos/Microsoft/vscode/...
# 5    https://api.github.com/repos/Microsoft/vscode/...
# 6    https://api.github.com/repos/Microsoft/vscode/...
# 7    https://api.github.com/repos/Microsoft/vscode/...
# 8    https://api.github.com/repos/Microsoft/vscode/...
# 9    https://api.github.com/repos/Microsoft/vscode/...
# 10   https://api.github.com/repos/Microsoft/vscode/...
# 11   https://api.github.com/repos/Microsoft/vscode/...
# 12   https://api.github.com/repos/Microsoft/vscode/...
# 13   https://api.github.com/repos/Microsoft/vscode/...
# 14   https://api.github.com/repos/Microsoft/vscode/...
# 15   https://api.github.com/repos/Microsoft/vscode/...
# 16   https://api.github.com/repos/Microsoft/vscode/...
# 17   https://api.github.com/repos/Microsoft/vscode/...
# 18   https://api.github.com/repos/Microsoft/vscode/...
# 19   https://api.github.com/repos/Microsoft/vscode/...
# 20   https://api.github.com/repos/Microsoft/vscode/...
# 21   https://api.github.com/repos/Microsoft/vscode/...
# 22   https://api.github.com/repos/Microsoft/vscode/...
# 23   https://api.github.com/repos/Microsoft/vscode/...
# 24   https://api.github.com/repos/Microsoft/vscode/...
# 25   https://api.github.com/repos/Microsoft/vscode/...
# 26   https://api.github.com/repos/Microsoft/vscode/...
# 27   https://api.github.com/repos/Microsoft/vscode/...
# 28   https://api.github.com/repos/Microsoft/vscode/...
# 29   https://api.github.com/repos/Microsoft/vscode/...
# ..                                                 ...
# 270  https://api.github.com/repos/Microsoft/vscode/...
# 271  https://api.github.com/repos/Microsoft/vscode/...
# 272  https://api.github.com/repos/Microsoft/vscode/...
# 273  https://api.github.com/repos/Microsoft/vscode/...
# 274  https://api.github.com/repos/Microsoft/vscode/...
# 275  https://api.github.com/repos/Microsoft/vscode/...
# 276  https://api.github.com/repos/Microsoft/vscode/...
# 277  https://api.github.com/repos/Microsoft/vscode/...
# 278  https://api.github.com/repos/Microsoft/vscode/...
# 279  https://api.github.com/repos/Microsoft/vscode/...
# 280  https://api.github.com/repos/Microsoft/vscode/...
# 281  https://api.github.com/repos/Microsoft/vscode/...
# 282  https://api.github.com/repos/Microsoft/vscode/...
# 283  https://api.github.com/repos/Microsoft/vscode/...
# 284  https://api.github.com/repos/Microsoft/vscode/...
# 285  https://api.github.com/repos/Microsoft/vscode/...
# 286  https://api.github.com/repos/Microsoft/vscode/...
# 287  https://api.github.com/repos/Microsoft/vscode/...
# 288  https://api.github.com/repos/Microsoft/vscode/...
# 289  https://api.github.com/repos/Microsoft/vscode/...
# 290  https://api.github.com/repos/Microsoft/vscode/...
# 291  https://api.github.com/repos/Microsoft/vscode/...
# 292  https://api.github.com/repos/Microsoft/vscode/...
# 293  https://api.github.com/repos/Microsoft/vscode/...
# 294  https://api.github.com/repos/Microsoft/vscode/...
# 295  https://api.github.com/repos/Microsoft/vscode/...
# 296  https://api.github.com/repos/Microsoft/vscode/...
# 297  https://api.github.com/repos/Microsoft/vscode/...
# 298  https://api.github.com/repos/Microsoft/vscode/...
# 299  https://api.github.com/repos/Microsoft/vscode/...
#
#                                              html_url   ...    \
# 0    https://github.com/Microsoft/vscode/issues/57779   ...
# 1    https://github.com/Microsoft/vscode/issues/57778   ...
# 2    https://github.com/Microsoft/vscode/issues/57777   ...
# 3    https://github.com/Microsoft/vscode/issues/57776   ...
# 4    https://github.com/Microsoft/vscode/issues/57775   ...
# 5    https://github.com/Microsoft/vscode/issues/57774   ...
# 6    https://github.com/Microsoft/vscode/issues/57773   ...
# 7    https://github.com/Microsoft/vscode/issues/57772   ...
# 8    https://github.com/Microsoft/vscode/issues/57771   ...
# 9    https://github.com/Microsoft/vscode/issues/57770   ...
# 10   https://github.com/Microsoft/vscode/issues/57768   ...
# 11   https://github.com/Microsoft/vscode/issues/57767   ...
# 12   https://github.com/Microsoft/vscode/issues/57766   ...
# 13   https://github.com/Microsoft/vscode/issues/57765   ...
# 14   https://github.com/Microsoft/vscode/issues/57764   ...
# 15   https://github.com/Microsoft/vscode/issues/57763   ...
# 16     https://github.com/Microsoft/vscode/pull/57762   ...
# 17   https://github.com/Microsoft/vscode/issues/57761   ...
# 18   https://github.com/Microsoft/vscode/issues/57760   ...
# 19   https://github.com/Microsoft/vscode/issues/57759   ...
# 20   https://github.com/Microsoft/vscode/issues/57758   ...
# 21   https://github.com/Microsoft/vscode/issues/57757   ...
# 22   https://github.com/Microsoft/vscode/issues/57756   ...
# 23   https://github.com/Microsoft/vscode/issues/57755   ...
# 24   https://github.com/Microsoft/vscode/issues/57754   ...
# 25   https://github.com/Microsoft/vscode/issues/57753   ...
# 26   https://github.com/Microsoft/vscode/issues/57751   ...
# 27   https://github.com/Microsoft/vscode/issues/57750   ...
# 28   https://github.com/Microsoft/vscode/issues/57749   ...
# 29   https://github.com/Microsoft/vscode/issues/57748   ...
# ..                                                ...   ...
# 270  https://github.com/Microsoft/vscode/issues/57779   ...
# 271  https://github.com/Microsoft/vscode/issues/57778   ...
# 272  https://github.com/Microsoft/vscode/issues/57777   ...
# 273  https://github.com/Microsoft/vscode/issues/57776   ...
# 274  https://github.com/Microsoft/vscode/issues/57775   ...
# 275  https://github.com/Microsoft/vscode/issues/57774   ...
# 276  https://github.com/Microsoft/vscode/issues/57773   ...
# 277  https://github.com/Microsoft/vscode/issues/57772   ...
# 278  https://github.com/Microsoft/vscode/issues/57771   ...
# 279  https://github.com/Microsoft/vscode/issues/57770   ...
# 280  https://github.com/Microsoft/vscode/issues/57768   ...
# 281  https://github.com/Microsoft/vscode/issues/57767   ...
# 282  https://github.com/Microsoft/vscode/issues/57766   ...
# 283  https://github.com/Microsoft/vscode/issues/57765   ...
# 284  https://github.com/Microsoft/vscode/issues/57764   ...
# 285  https://github.com/Microsoft/vscode/issues/57763   ...
# 286    https://github.com/Microsoft/vscode/pull/57762   ...
# 287  https://github.com/Microsoft/vscode/issues/57761   ...
# 288  https://github.com/Microsoft/vscode/issues/57760   ...
# 289  https://github.com/Microsoft/vscode/issues/57759   ...
# 290  https://github.com/Microsoft/vscode/issues/57758   ...
# 291  https://github.com/Microsoft/vscode/issues/57757   ...
# 292  https://github.com/Microsoft/vscode/issues/57756   ...
# 293  https://github.com/Microsoft/vscode/issues/57755   ...
# 294  https://github.com/Microsoft/vscode/issues/57754   ...
# 295  https://github.com/Microsoft/vscode/issues/57753   ...
# 296  https://github.com/Microsoft/vscode/issues/57751   ...
# 297  https://github.com/Microsoft/vscode/issues/57750   ...
# 298  https://github.com/Microsoft/vscode/issues/57749   ...
# 299  https://github.com/Microsoft/vscode/issues/57748   ...
#
#                                     repository_url state  \
# 0    https://api.github.com/repos/Microsoft/vscode  open
# 1    https://api.github.com/repos/Microsoft/vscode  open
# 2    https://api.github.com/repos/Microsoft/vscode  open
# 3    https://api.github.com/repos/Microsoft/vscode  open
# 4    https://api.github.com/repos/Microsoft/vscode  open
# 5    https://api.github.com/repos/Microsoft/vscode  open
# 6    https://api.github.com/repos/Microsoft/vscode  open
# 7    https://api.github.com/repos/Microsoft/vscode  open
# 8    https://api.github.com/repos/Microsoft/vscode  open
# 9    https://api.github.com/repos/Microsoft/vscode  open
# 10   https://api.github.com/repos/Microsoft/vscode  open
# 11   https://api.github.com/repos/Microsoft/vscode  open
# 12   https://api.github.com/repos/Microsoft/vscode  open
# 13   https://api.github.com/repos/Microsoft/vscode  open
# 14   https://api.github.com/repos/Microsoft/vscode  open
# 15   https://api.github.com/repos/Microsoft/vscode  open
# 16   https://api.github.com/repos/Microsoft/vscode  open
# 17   https://api.github.com/repos/Microsoft/vscode  open
# 18   https://api.github.com/repos/Microsoft/vscode  open
# 19   https://api.github.com/repos/Microsoft/vscode  open
# 20   https://api.github.com/repos/Microsoft/vscode  open
# 21   https://api.github.com/repos/Microsoft/vscode  open
# 22   https://api.github.com/repos/Microsoft/vscode  open
# 23   https://api.github.com/repos/Microsoft/vscode  open
# 24   https://api.github.com/repos/Microsoft/vscode  open
# 25   https://api.github.com/repos/Microsoft/vscode  open
# 26   https://api.github.com/repos/Microsoft/vscode  open
# 27   https://api.github.com/repos/Microsoft/vscode  open
# 28   https://api.github.com/repos/Microsoft/vscode  open
# 29   https://api.github.com/repos/Microsoft/vscode  open
# ..                                             ...   ...
# 270  https://api.github.com/repos/Microsoft/vscode  open
# 271  https://api.github.com/repos/Microsoft/vscode  open
# 272  https://api.github.com/repos/Microsoft/vscode  open
# 273  https://api.github.com/repos/Microsoft/vscode  open
# 274  https://api.github.com/repos/Microsoft/vscode  open
# 275  https://api.github.com/repos/Microsoft/vscode  open
# 276  https://api.github.com/repos/Microsoft/vscode  open
# 277  https://api.github.com/repos/Microsoft/vscode  open
# 278  https://api.github.com/repos/Microsoft/vscode  open
# 279  https://api.github.com/repos/Microsoft/vscode  open
# 280  https://api.github.com/repos/Microsoft/vscode  open
# 281  https://api.github.com/repos/Microsoft/vscode  open
# 282  https://api.github.com/repos/Microsoft/vscode  open
# 283  https://api.github.com/repos/Microsoft/vscode  open
# 284  https://api.github.com/repos/Microsoft/vscode  open
# 285  https://api.github.com/repos/Microsoft/vscode  open
# 286  https://api.github.com/repos/Microsoft/vscode  open
# 287  https://api.github.com/repos/Microsoft/vscode  open
# 288  https://api.github.com/repos/Microsoft/vscode  open
# 289  https://api.github.com/repos/Microsoft/vscode  open
# 290  https://api.github.com/repos/Microsoft/vscode  open
# 291  https://api.github.com/repos/Microsoft/vscode  open
# 292  https://api.github.com/repos/Microsoft/vscode  open
# 293  https://api.github.com/repos/Microsoft/vscode  open
# 294  https://api.github.com/repos/Microsoft/vscode  open
# 295  https://api.github.com/repos/Microsoft/vscode  open
# 296  https://api.github.com/repos/Microsoft/vscode  open
# 297  https://api.github.com/repos/Microsoft/vscode  open
# 298  https://api.github.com/repos/Microsoft/vscode  open
# 299  https://api.github.com/repos/Microsoft/vscode  open
#
#                                                  title          updated_at  \
# 0                                          3septiembre 2018-09-02 15:21:49
# 1          Editor locks up after about 1 hour of usage 2018-09-02 15:22:41
# 2    Whole file content erased when it failed to sa... 2018-09-02 15:43:09
# 3          Segmentation fault in Ubuntu Cosmic (18.10) 2018-09-02 14:42:19
# 4        Find in Files: newline matches the whole line 2018-09-02 14:17:38
# 5                          Minimum Window size default 2018-09-02 14:03:28
# 6             Blurry text on menus and layout on MacOS 2018-09-02 13:03:15
# 7    The program runs fine, but some of the code on... 2018-09-02 12:11:31
# 8                       C++ class name not highlighted 2018-09-02 10:08:15
# 9    Extensions editor: editor not focused when cli... 2018-09-02 08:56:16
# 10               Javascript syntax string highlighting 2018-09-02 07:38:09
# 11                                    Weird Pylint bug 2018-09-02 06:49:58
# 12   Dragging files and other draggable items cause... 2018-09-02 04:02:23
# 13   Switch LF as line end appears text blur on win... 2018-09-02 03:18:38
# 14                Debugger for Java suddenly can't run 2018-09-02 03:17:03
# 15   No oportunity to work on multi-screen environm... 2018-09-02 01:25:31
# 16                  Add editor.restoreViewState option 2018-09-01 22:21:27
# 17          Active workspace detection for launch.json 2018-09-01 22:26:19
# 18   Ability to run multiple launch events sequenti... 2018-09-01 22:24:54
# 19                    Se necesita agregar mas opciones 2018-09-01 21:33:55
# 20               Output window is showing incorrect UI 2018-09-01 20:58:33
# 21   Setting default `executable` in ShellExecution... 2018-09-01 20:29:20
# 22   No menu overflow causes problems with narrow w... 2018-09-01 20:11:24
# 23                                 Try after installed 2018-09-01 19:17:56
# 24   Emmet 'Wrap with Abbreviation' doesn't work in... 2018-09-01 18:50:57
# 25   Option to insert comment // characters at colu... 2018-09-01 18:26:16
# 26     Nested tabstops in snippets behaves incorrectly 2018-09-01 18:04:06
# 27   Request for Access to Ambient Light Sensor in ... 2018-09-01 17:13:34
# 28   TextDocumentContentProvider renders gibberish ... 2018-09-01 15:30:44
# 29              I do not see the Markdown Preview icon 2018-09-01 17:20:28
# ..                                                 ...                 ...
# 270                                        3septiembre 2018-09-02 15:21:49
# 271        Editor locks up after about 1 hour of usage 2018-09-02 15:22:41
# 272  Whole file content erased when it failed to sa... 2018-09-02 15:43:09
# 273        Segmentation fault in Ubuntu Cosmic (18.10) 2018-09-02 14:42:19
# 274      Find in Files: newline matches the whole line 2018-09-02 14:17:38
# 275                        Minimum Window size default 2018-09-02 14:03:28
# 276           Blurry text on menus and layout on MacOS 2018-09-02 13:03:15
# 277  The program runs fine, but some of the code on... 2018-09-02 12:11:31
# 278                     C++ class name not highlighted 2018-09-02 10:08:15
# 279  Extensions editor: editor not focused when cli... 2018-09-02 08:56:16
# 280              Javascript syntax string highlighting 2018-09-02 07:38:09
# 281                                   Weird Pylint bug 2018-09-02 06:49:58
# 282  Dragging files and other draggable items cause... 2018-09-02 04:02:23
# 283  Switch LF as line end appears text blur on win... 2018-09-02 03:18:38
# 284               Debugger for Java suddenly can't run 2018-09-02 03:17:03
# 285  No oportunity to work on multi-screen environm... 2018-09-02 01:25:31
# 286                 Add editor.restoreViewState option 2018-09-01 22:21:27
# 287         Active workspace detection for launch.json 2018-09-01 22:26:19
# 288  Ability to run multiple launch events sequenti... 2018-09-01 22:24:54
# 289                   Se necesita agregar mas opciones 2018-09-01 21:33:55
# 290              Output window is showing incorrect UI 2018-09-01 20:58:33
# 291  Setting default `executable` in ShellExecution... 2018-09-01 20:29:20
# 292  No menu overflow causes problems with narrow w... 2018-09-01 20:11:24
# 293                                Try after installed 2018-09-01 19:17:56
# 294  Emmet 'Wrap with Abbreviation' doesn't work in... 2018-09-01 18:50:57
# 295  Option to insert comment // characters at colu... 2018-09-01 18:26:16
# 296    Nested tabstops in snippets behaves incorrectly 2018-09-01 18:04:06
# 297  Request for Access to Ambient Light Sensor in ... 2018-09-01 17:13:34
# 298  TextDocumentContentProvider renders gibberish ... 2018-09-01 15:30:44
# 299             I do not see the Markdown Preview icon 2018-09-01 17:20:28
#
#                                                    url  \
# 0    https://api.github.com/repos/Microsoft/vscode/...
# 1    https://api.github.com/repos/Microsoft/vscode/...
# 2    https://api.github.com/repos/Microsoft/vscode/...
# 3    https://api.github.com/repos/Microsoft/vscode/...
# 4    https://api.github.com/repos/Microsoft/vscode/...
# 5    https://api.github.com/repos/Microsoft/vscode/...
# 6    https://api.github.com/repos/Microsoft/vscode/...
# 7    https://api.github.com/repos/Microsoft/vscode/...
# 8    https://api.github.com/repos/Microsoft/vscode/...
# 9    https://api.github.com/repos/Microsoft/vscode/...
# 10   https://api.github.com/repos/Microsoft/vscode/...
# 11   https://api.github.com/repos/Microsoft/vscode/...
# 12   https://api.github.com/repos/Microsoft/vscode/...
# 13   https://api.github.com/repos/Microsoft/vscode/...
# 14   https://api.github.com/repos/Microsoft/vscode/...
# 15   https://api.github.com/repos/Microsoft/vscode/...
# 16   https://api.github.com/repos/Microsoft/vscode/...
# 17   https://api.github.com/repos/Microsoft/vscode/...
# 18   https://api.github.com/repos/Microsoft/vscode/...
# 19   https://api.github.com/repos/Microsoft/vscode/...
# 20   https://api.github.com/repos/Microsoft/vscode/...
# 21   https://api.github.com/repos/Microsoft/vscode/...
# 22   https://api.github.com/repos/Microsoft/vscode/...
# 23   https://api.github.com/repos/Microsoft/vscode/...
# 24   https://api.github.com/repos/Microsoft/vscode/...
# 25   https://api.github.com/repos/Microsoft/vscode/...
# 26   https://api.github.com/repos/Microsoft/vscode/...
# 27   https://api.github.com/repos/Microsoft/vscode/...
# 28   https://api.github.com/repos/Microsoft/vscode/...
# 29   https://api.github.com/repos/Microsoft/vscode/...
# ..                                                 ...
# 270  https://api.github.com/repos/Microsoft/vscode/...
# 271  https://api.github.com/repos/Microsoft/vscode/...
# 272  https://api.github.com/repos/Microsoft/vscode/...
# 273  https://api.github.com/repos/Microsoft/vscode/...
# 274  https://api.github.com/repos/Microsoft/vscode/...
# 275  https://api.github.com/repos/Microsoft/vscode/...
# 276  https://api.github.com/repos/Microsoft/vscode/...
# 277  https://api.github.com/repos/Microsoft/vscode/...
# 278  https://api.github.com/repos/Microsoft/vscode/...
# 279  https://api.github.com/repos/Microsoft/vscode/...
# 280  https://api.github.com/repos/Microsoft/vscode/...
# 281  https://api.github.com/repos/Microsoft/vscode/...
# 282  https://api.github.com/repos/Microsoft/vscode/...
# 283  https://api.github.com/repos/Microsoft/vscode/...
# 284  https://api.github.com/repos/Microsoft/vscode/...
# 285  https://api.github.com/repos/Microsoft/vscode/...
# 286  https://api.github.com/repos/Microsoft/vscode/...
# 287  https://api.github.com/repos/Microsoft/vscode/...
# 288  https://api.github.com/repos/Microsoft/vscode/...
# 289  https://api.github.com/repos/Microsoft/vscode/...
# 290  https://api.github.com/repos/Microsoft/vscode/...
# 291  https://api.github.com/repos/Microsoft/vscode/...
# 292  https://api.github.com/repos/Microsoft/vscode/...
# 293  https://api.github.com/repos/Microsoft/vscode/...
# 294  https://api.github.com/repos/Microsoft/vscode/...
# 295  https://api.github.com/repos/Microsoft/vscode/...
# 296  https://api.github.com/repos/Microsoft/vscode/...
# 297  https://api.github.com/repos/Microsoft/vscode/...
# 298  https://api.github.com/repos/Microsoft/vscode/...
# 299  https://api.github.com/repos/Microsoft/vscode/...
#
#                                                   user  \
# 0    {'login': 'TIVelez', 'id': 28053684, 'node_id'...
# 1    {'login': 'TheColorRed', 'id': 1571806, 'node_...
# 2    {'login': 'vasu-msbits', 'id': 1105258, 'node_...
# 3    {'login': 'fenris', 'id': 405473, 'node_id': '...
# 4    {'login': 'anthonyvdotbe', 'id': 15714253, 'no...
# 5    {'login': 'DanaMW', 'id': 12940577, 'node_id':...
# 6    {'login': 'Ant-V', 'id': 7198995, 'node_id': '...
# 7    {'login': 'wanghaooo', 'id': 26863173, 'node_i...
# 8    {'login': 'obhi-d', 'id': 7620636, 'node_id': ...
# 9    {'login': 'bpasero', 'id': 900690, 'node_id': ...
# 10   {'login': 'zicsus', 'id': 31795543, 'node_id':...
# 11   {'login': 'youssefsharief', 'id': 21158003, 'n...
# 12   {'login': 'chrisdruta', 'id': 8966862, 'node_i...
# 13   {'login': 'bursto7', 'id': 11030027, 'node_id'...
# 14   {'login': 'bobjiang1988', 'id': 5567404, 'node...
# 15   {'login': 'phpwarrior', 'id': 42901712, 'node_...
# 16   {'login': 'aviddiviner', 'id': 835967, 'node_i...
# 17   {'login': 'richbully', 'id': 11023398, 'node_i...
# 18   {'login': 'ChaosCA', 'id': 5280764, 'node_id':...
# 19   {'login': 'WilsonGrave', 'id': 42899255, 'node...
# 20   {'login': 'wizchick7', 'id': 1242893, 'node_id...
# 21   {'login': 'busticated', 'id': 367674, 'node_id...
# 22   {'login': 'Tyriar', 'id': 2193314, 'node_id': ...
# 23   {'login': 'transdigiware', 'id': 34800339, 'no...
# 24   {'login': 'bencun', 'id': 15714548, 'node_id':...
# 25   {'login': 's-kocher', 'id': 27820864, 'node_id...
# 26   {'login': 'yangshuairocks', 'id': 39968, 'node...
# 27   {'login': 'pmkary', 'id': 2157285, 'node_id': ...
# 28   {'login': 'Almenon', 'id': 13080965, 'node_id'...
# 29   {'login': 'pelos6', 'id': 3807895, 'node_id': ...
# ..                                                 ...
# 270  {'login': 'TIVelez', 'id': 28053684, 'node_id'...
# 271  {'login': 'TheColorRed', 'id': 1571806, 'node_...
# 272  {'login': 'vasu-msbits', 'id': 1105258, 'node_...
# 273  {'login': 'fenris', 'id': 405473, 'node_id': '...
# 274  {'login': 'anthonyvdotbe', 'id': 15714253, 'no...
# 275  {'login': 'DanaMW', 'id': 12940577, 'node_id':...
# 276  {'login': 'Ant-V', 'id': 7198995, 'node_id': '...
# 277  {'login': 'wanghaooo', 'id': 26863173, 'node_i...
# 278  {'login': 'obhi-d', 'id': 7620636, 'node_id': ...
# 279  {'login': 'bpasero', 'id': 900690, 'node_id': ...
# 280  {'login': 'zicsus', 'id': 31795543, 'node_id':...
# 281  {'login': 'youssefsharief', 'id': 21158003, 'n...
# 282  {'login': 'chrisdruta', 'id': 8966862, 'node_i...
# 283  {'login': 'bursto7', 'id': 11030027, 'node_id'...
# 284  {'login': 'bobjiang1988', 'id': 5567404, 'node...
# 285  {'login': 'phpwarrior', 'id': 42901712, 'node_...
# 286  {'login': 'aviddiviner', 'id': 835967, 'node_i...
# 287  {'login': 'richbully', 'id': 11023398, 'node_i...
# 288  {'login': 'ChaosCA', 'id': 5280764, 'node_id':...
# 289  {'login': 'WilsonGrave', 'id': 42899255, 'node...
# 290  {'login': 'wizchick7', 'id': 1242893, 'node_id...
# 291  {'login': 'busticated', 'id': 367674, 'node_id...
# 292  {'login': 'Tyriar', 'id': 2193314, 'node_id': ...
# 293  {'login': 'transdigiware', 'id': 34800339, 'no...
# 294  {'login': 'bencun', 'id': 15714548, 'node_id':...
# 295  {'login': 's-kocher', 'id': 27820864, 'node_id...
# 296  {'login': 'yangshuairocks', 'id': 39968, 'node...
# 297  {'login': 'pmkary', 'id': 2157285, 'node_id': ...
# 298  {'login': 'Almenon', 'id': 13080965, 'node_id'...
# 299  {'login': 'pelos6', 'id': 3807895, 'node_id': ...
#
#                   label_names  isBug   isFR isOther
# 0                  extensions  False  False    True
# 1         integrated-terminal  False  False    True
# 2             needs more info  False  False    True
# 3              install-update  False  False    True
# 4          editor,editor-find  False  False    True
# 5                   no_labels  False  False    True
# 6                   no_labels  False  False    True
# 7                  javascript  False  False    True
# 8                   no_labels  False  False    True
# 9                         bug   True  False   False
# 10                 javascript  False  False    True
# 11                  no_labels  False  False    True
# 12             install-update  False  False    True
# 13      editor,editor-contrib  False  False    True
# 14                  no_labels  False  False    True
# 15                  no_labels  False  False    True
# 16                  no_labels  False  False    True
# 17   debug,feature-request,ux   True   True   False
# 18      debug,feature-request   True   True   False
# 19                  no_labels  False  False    True
# 20                   insiders  False  False    True
# 21        integrated-terminal  False  False    True
# 22         bug,workbench-menu   True  False   False
# 23                  no_labels  False  False    True
# 24                      emmet  False  False    True
# 25      editor,editor-contrib  False  False    True
# 26                  no_labels  False  False    True
# 27                  no_labels  False  False    True
# 28                  no_labels  False  False    True
# 29                   markdown  False  False    True
# ..                        ...    ...    ...     ...
# 270                extensions  False  False    True
# 271       integrated-terminal  False  False    True
# 272           needs more info  False  False    True
# 273            install-update  False  False    True
# 274        editor,editor-find  False  False    True
# 275                 no_labels  False  False    True
# 276                 no_labels  False  False    True
# 277                javascript  False  False    True
# 278                 no_labels  False  False    True
# 279                       bug   True  False   False
# 280                javascript  False  False    True
# 281                 no_labels  False  False    True
# 282            install-update  False  False    True
# 283     editor,editor-contrib  False  False    True
# 284                 no_labels  False  False    True
# 285                 no_labels  False  False    True
# 286                 no_labels  False  False    True
# 287  debug,feature-request,ux   True   True   False
# 288     debug,feature-request   True   True   False
# 289                 no_labels  False  False    True
# 290                  insiders  False  False    True
# 291       integrated-terminal  False  False    True
# 292        bug,workbench-menu   True  False   False
# 293                 no_labels  False  False    True
# 294                     emmet  False  False    True
# 295     editor,editor-contrib  False  False    True
# 296                 no_labels  False  False    True
# 297                 no_labels  False  False    True
# 298                 no_labels  False  False    True
# 299                  markdown  False  False    True
#
# [300 rows x 28 columns]

# %% [markdown]
# ### Extraire les variables qui m'interesse

# %%
col = ['label_names','body','isFR']
dcol = d[col]
dcol
# Out:
#                   label_names  \
# 0                  extensions
# 1         integrated-terminal
# 2             needs more info
# 3              install-update
# 4          editor,editor-find
# 5                   no_labels
# 6                   no_labels
# 7                  javascript
# 8                   no_labels
# 9                         bug
# 10                 javascript
# 11                  no_labels
# 12             install-update
# 13      editor,editor-contrib
# 14                  no_labels
# 15                  no_labels
# 16                  no_labels
# 17   debug,feature-request,ux
# 18      debug,feature-request
# 19                  no_labels
# 20                   insiders
# 21        integrated-terminal
# 22         bug,workbench-menu
# 23                  no_labels
# 24                      emmet
# 25      editor,editor-contrib
# 26                  no_labels
# 27                  no_labels
# 28                  no_labels
# 29                   markdown
# ..                        ...
# 270                extensions
# 271       integrated-terminal
# 272           needs more info
# 273            install-update
# 274        editor,editor-find
# 275                 no_labels
# 276                 no_labels
# 277                javascript
# 278                 no_labels
# 279                       bug
# 280                javascript
# 281                 no_labels
# 282            install-update
# 283     editor,editor-contrib
# 284                 no_labels
# 285                 no_labels
# 286                 no_labels
# 287  debug,feature-request,ux
# 288     debug,feature-request
# 289                 no_labels
# 290                  insiders
# 291       integrated-terminal
# 292        bug,workbench-menu
# 293                 no_labels
# 294                     emmet
# 295     editor,editor-contrib
# 296                 no_labels
# 297                 no_labels
# 298                 no_labels
# 299                  markdown
#
#                                                   body   isFR
# 0    <!-- Please search existing issues to avoid cr...  False
# 1    Issue Type: <b>Bug</b>\r\n\r\nAfter updating f...  False
# 2    <!-- Please search existing issues to avoid cr...  False
# 3    <!-- Please search existing issues to avoid cr...  False
# 4    - VSCode Version: Version: 1.26.1 (Commit: 493...  False
# 5    Issue Type: <b>Suspected Bug</b>\r\n\r\nI had ...  False
# 6    Issue Type: <b>Bug</b>\r\n\r\nSome menu items ...  False
# 7    VSCode Version: 1.26.1\r\nOS Version: MacOS\r\...  False
# 8    <!-- Please search existing issues to avoid cr...  False
# 9    - OS Version: macOS\r\n\r\nSteps to Reproduce:...  False
# 10   Issue Type: <b>Bug</b>\r\n\r\nWhen you make a ...  False
# 11   Pylint does not work in vs code if one of the ...  False
# 12   - VSCode Version: 1.26.1, 493869ee8e8a846b0855...  False
# 13   Issue Type: <b>Bug</b>\r\n\r\nBy default, ther...  False
# 14   The debugger for Java suddenly can't run.\r\nB...  False
# 15   I can open a new window, but it isn't cooperat...  False
# 16   This option will allow opt-out of restoring sc...  False
# 17   I have a very large web application with 21 mu...   True
# 18   Currently you can use compound launch configur...   True
# 19   Seria bueno de irme abrir el vinculo delas cap...  False
# 20   Issue Type: <b>Bug</b>\r\n\r\nInstall VSCode I...  False
# 21   hi again :wave:\r\n\r\ni'm trying to customize...  False
# 22   ![image](https://user-images.githubusercontent...  False
# 23   Issue Type: <b>Bug</b>\r\n\r\nlooking another ...  False
# 24   Issue Type: <b>Bug</b>\r\n\r\nSteps to reprodu...  False
# 25   I recreate this formerly closed feature reques...  False
# 26   <!-- Please search existing issues to avoid cr...  False
# 27   > __NOTE__\r\n> There is a duplicate and simil...  False
# 28   <!-- Please search existing issues to avoid cr...  False
# 29   \r\nIssue Type: <b>Bug</b>\r\n\r\nI expected t...  False
# ..                                                 ...    ...
# 270  <!-- Please search existing issues to avoid cr...  False
# 271  Issue Type: <b>Bug</b>\r\n\r\nAfter updating f...  False
# 272  <!-- Please search existing issues to avoid cr...  False
# 273  <!-- Please search existing issues to avoid cr...  False
# 274  - VSCode Version: Version: 1.26.1 (Commit: 493...  False
# 275  Issue Type: <b>Suspected Bug</b>\r\n\r\nI had ...  False
# 276  Issue Type: <b>Bug</b>\r\n\r\nSome menu items ...  False
# 277  VSCode Version: 1.26.1\r\nOS Version: MacOS\r\...  False
# 278  <!-- Please search existing issues to avoid cr...  False
# 279  - OS Version: macOS\r\n\r\nSteps to Reproduce:...  False
# 280  Issue Type: <b>Bug</b>\r\n\r\nWhen you make a ...  False
# 281  Pylint does not work in vs code if one of the ...  False
# 282  - VSCode Version: 1.26.1, 493869ee8e8a846b0855...  False
# 283  Issue Type: <b>Bug</b>\r\n\r\nBy default, ther...  False
# 284  The debugger for Java suddenly can't run.\r\nB...  False
# 285  I can open a new window, but it isn't cooperat...  False
# 286  This option will allow opt-out of restoring sc...  False
# 287  I have a very large web application with 21 mu...   True
# 288  Currently you can use compound launch configur...   True
# 289  Seria bueno de irme abrir el vinculo delas cap...  False
# 290  Issue Type: <b>Bug</b>\r\n\r\nInstall VSCode I...  False
# 291  hi again :wave:\r\n\r\ni'm trying to customize...  False
# 292  ![image](https://user-images.githubusercontent...  False
# 293  Issue Type: <b>Bug</b>\r\n\r\nlooking another ...  False
# 294  Issue Type: <b>Bug</b>\r\n\r\nSteps to reprodu...  False
# 295  I recreate this formerly closed feature reques...  False
# 296  <!-- Please search existing issues to avoid cr...  False
# 297  > __NOTE__\r\n> There is a duplicate and simil...  False
# 298  <!-- Please search existing issues to avoid cr...  False
# 299  \r\nIssue Type: <b>Bug</b>\r\n\r\nI expected t...  False
#
# [300 rows x 3 columns]

# %%
from io import StringIO
col = ['label_names', 'body','isFR']
d = d[col]
d.columns = ['label_names', 'body','isFR']
d['category_id'] = d['isFR'].factorize()[0]
category_id_d = d[['isFR', 'category_id']].drop_duplicates().sort_values('category_id')
category_to_id = dict(category_id_d.values)
id_to_category = dict(category_id_d[['category_id', 'isFR']].values)
d.head()
# Out:
# c:\users\thouderth\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#            label_names                                               body  \
# 0           extensions  <!-- Please search existing issues to avoid cr...
# 1  integrated-terminal  Issue Type: <b>Bug</b>\r\n\r\nAfter updating f...
# 2      needs more info  <!-- Please search existing issues to avoid cr...
# 3       install-update  <!-- Please search existing issues to avoid cr...
# 4   editor,editor-find  - VSCode Version: Version: 1.26.1 (Commit: 493...
#
#     isFR  category_id
# 0  False            0
# 1  False            0
# 2  False            0
# 3  False            0
# 4  False            0

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')

features = tfidf.fit_transform(d.body).toarray()
labels = d.category_id
features.shape
# Out:
# (300, 3535)

# %%
from sklearn.feature_selection import chi2
import numpy as np
N = 2
for label_names, category_id in sorted(category_to_id.items()):
  features_chi2 = chi2(features, labels == category_id)
  indices = np.argsort(features_chi2[0])
  feature_names = np.array(tfidf.get_feature_names())[indices]
  unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
  bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
  print("# '{}':".format(label_names))
  print("  . Most correlated unigrams:\n. {}".format('\n. '.join(unigrams[-N:])))
  print("  . Most correlated bigrams:\n. {}".format('\n. '.join(bigrams[-N:])))
# Out:
# # 'False':
#   . Most correlated unigrams:
# . configurations
# . server
#   . Most correlated bigrams:
# . node request
# . launch json
# # 'True':
#   . Most correlated unigrams:
# . configurations
# . server
#   . Most correlated bigrams:
# . node request
# . launch json

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
X_train, X_test, y_train, y_test = train_test_split(d['body'], d['isFR'], random_state = 0)
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
clf
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
d['body'][0]
# Out:
# '<!-- Please search existing issues to avoid creating duplicates. --> \r\n<!-- Also please test using the latest insiders build to make sure your issue has not already been fixed: https://code.visualstudio.com/insiders/ -->\r\n\r\n<!-- Use Help > Report Issue to prefill these. -->\r\n- VSCode Version:\r\n- OS Version:\r\n\r\nSteps to Reproduce:\r\n\r\n1.\r\n2.\r\n\r\n<!-- Launch with `code --disable-extensions` to check. -->\r\nDoes this issue occur when all extensions are disabled?: Yes/No\r\n'

# %%
print(clf.predict(count_vect.transform(["<!-- Please search existing issues to avoid creating duplicates. --> \r\n<!-- Also please test using the latest insiders build to make sure your issue has not already been fixed: https://code.visualstudio.com/insiders/ -->\r\n\r\n<!-- Use Help > Report Issue to prefill these. -->\r\n- VSCode Version:\r\n- OS Version:\r\n\r\nSteps to Reproduce:\r\n\r\n1.\r\n2.\r\n\r\n<!-- Launch with `code --disable-extensions` to check. -->\r\nDoes this issue occur when all extensions are disabled?: Yes/No\r\n"])))
# Out:
# [False]

# %%
d[d['body'] == "<!-- Please search existing issues to avoid creating duplicates. --> \r\n<!-- Also please test using the latest insiders build to make sure your issue has not already been fixed: https://code.visualstudio.com/insiders/ -->\r\n\r\n<!-- Use Help > Report Issue to prefill these. -->\r\n- VSCode Version:\r\n- OS Version:\r\n\r\nSteps to Reproduce:\r\n\r\n1.\r\n2.\r\n\r\n<!-- Launch with `code --disable-extensions` to check. -->\r\nDoes this issue occur when all extensions are disabled?: Yes/No\r\n"]
# Out:
#     label_names                                               body   isFR  \
# 0    extensions  <!-- Please search existing issues to avoid cr...  False
# 30   extensions  <!-- Please search existing issues to avoid cr...  False
# 60   extensions  <!-- Please search existing issues to avoid cr...  False
# 90   extensions  <!-- Please search existing issues to avoid cr...  False
# 120  extensions  <!-- Please search existing issues to avoid cr...  False
# 150  extensions  <!-- Please search existing issues to avoid cr...  False
# 180  extensions  <!-- Please search existing issues to avoid cr...  False
# 210  extensions  <!-- Please search existing issues to avoid cr...  False
# 240  extensions  <!-- Please search existing issues to avoid cr...  False
# 270  extensions  <!-- Please search existing issues to avoid cr...  False
#
#      category_id
# 0              0
# 30             0
# 60             0
# 90             0
# 120            0
# 150            0
# 180            0
# 210            0
# 240            0
# 270            0

# %% [markdown]
# ### Tester d'autre modeles de machine learning

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
models = [
    RandomForestClassifier(n_estimators=200, max_depth=3, random_state=0),
    LinearSVC(),
    MultinomialNB(),
    LogisticRegression(random_state=0),
]
CV=5
cv_d = pd.DataFrame(index=range(CV * len(models)))
entries = []
for model in models:
    model_name = model.__class__.__name__
    accuracies = cross_val_score(model, features, labels, scoring='accuracy', cv=CV)
    for fold_idx, accuracy in enumerate(accuracies):
        entries.append((model_name, fold_idx, accuracy))
cv_d = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])
cv_d.groupby('model_name').accuracy.mean()
# Out:
# model_name
# LinearSVC                 1.0
# LogisticRegression        1.0
# MultinomialNB             1.0
# RandomForestClassifier    1.0
# Name: accuracy, dtype: float64
